# %% [markdown]
# # Anthropic Financial Analyst Agent with Real-time News Access (built with LlamaIndex)

# %% [markdown]
# ## 1. Process <br>
# this notebook is designed to retrieve financial data about a stock or company:
#
# ### Tools used:
#
#
# 1.   Anthropic API - Claude 3.5 Sonnett
# 2.   LlamaIndex for orchestration
# 3.   Financial Modeling Prep API for stock information
# 4.   News API for news summarization

# %%
# !pip install llama-index-llms-anthropic -q
# !pip install llama-index -q

# %%
from llama_index.llms.anthropic import Anthropic
from llama_index.llms.openai import OpenAI
from llama_index.core.tools import FunctionTool

import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ## 2. Instantiate Anthropic and News API Keys

# %% [markdown]
# Step 1: Instantiate Baseline LLM to be used
#
#
# *   Experiment 1: Use Claude Sonnet for tool use, code generation and parsing
# *   Experiment 2: Use OpenAI o1 models to test reasoning capabilities

# %%
from google.colab import userdata

CLAUDE_API_KEY = userdata.get('ANTHROPIC_API_KEY')
OAI_API_KEY = userdata.get('OPENAI_API_KEY')
FMP_API_KEY = userdata.get('FINANCIAL_MODELING_PREP_API_KEY')

# %%
openai_llm = OpenAI(model="gpt-4o-mini", api_key=OAI_API_KEY)

# %%
anthropic_llm = Anthropic(model="claude-3-5-sonnet-20240620", api_key=CLAUDE_API_KEY)

# %% [markdown]
# Step 2: Instantiate News API for Retrieval

# %% [markdown]
# ## 3. Define Tools for LLM Use

# %% [markdown]
# ### 3.1. Stock Price Function - get_stock_price

# %%
import os
import requests

# Define the function that will retrieve the financial data

def get_stock_price(symbol):
    """
    Fetch the current stock price for the given symbol, the current stock trading volume, the average 50-day, 200-day moving average price,
    Earnings per share (EPS), price/earnings (P/E) ratio, and the next earnings Announcement.
    """
    url = f"https://financialmodelingprep.com/api/v3/quote-order/{symbol}?apikey={FMP_API_KEY}"
    response = requests.get(url)
    data = response.json()
    try:
        price = data[0]['price']
        volume = data[0]['volume']
        avgVolume = data[0]['avgVolume']
        priceAvg50 = data[0]['priceAvg50']
        priceAvg200 = data[0]['priceAvg200']
        eps = data[0]['eps']
        pe = data[0]['pe']
        earningsAnnouncement = data[0]['earningsAnnouncement']
        return {"symbol": symbol.upper(), "price": price, "volume": volume, "avgVolume": avgVolume, "priceAvg50": priceAvg50, "priceAvg200": priceAvg200, "EPS": eps, "PE": pe, "earningsAnnouncement": earningsAnnouncement}
    except (IndexError, KeyError):
        return {"error": f"Invalid symbol or data not available for {symbol}"}


## DATA FORMAT OF THE STOCK PRICE FULL DATA ENDPOINT - FREE ENDPOINT (v3)
# [
# 	{
# 		"symbol": "AAPL",
# 		"name": "Apple Inc.",
# 		"price": 145.855,
# 		"changesPercentage": 0.3751,
# 		"change": 0.545,
# 		"dayLow": 143.9,
# 		"dayHigh": 146.71,
# 		"yearHigh": 179.61,
# 		"yearLow": 124.17,
# 		"marketCap": 2307703191828,
# 		"priceAvg50": 140.8724,
# 		"priceAvg200": 147.18594,
# 		"exchange": "NASDAQ",
# 		"volume": 42609394,
# 		"avgVolume": 73638864,
# 		"open": 144.38,
# 		"previousClose": 145.31,
# 		"eps": 5.89,
# 		"pe": 24.76,
# 		"earningsAnnouncement": "2023-04-26T10:59:00.000+0000",
# 		"sharesOutstanding": 15821899776,
# 		"timestamp": 1677790784
# 	}
# ]

# %% [markdown]
# ### 3.2. Retrieve Company Financials - get_company_financials

# %%
def get_company_financials(symbol):
  """
  Fetch basic financial information for the given company symbol such as the␣
  industry, the sector, the name of the company, and the market capitalization.
  """
  url = f"https://financialmodelingprep.com/api/v3/profile/{symbol}?apikey={FMP_API_KEY}"
  response = requests.get(url)
  data = response.json()
  try:
    results = data[0]
    financials = {
    "symbol": results["symbol"],
    "companyName": results["companyName"],
    "marketCap": results["mktCap"],
    "industry": results["industry"],
    "sector": results["sector"],
    "website": results["website"],
    "beta":results["beta"],
    "price":results["price"],
    }
    return financials
  except (IndexError, KeyError):
    return {"error": f"Invalid symbol or data not available for {symbol}"}

## DATA FORMAT OF THE STOCK PROFILE FULL DATA ENDPOINT - FREE ENDPOINT (v3)
# [
# 	{
# 		"symbol": "AAPL",
# 		"price": 178.72,
# 		"beta": 1.286802,
# 		"volAvg": 58405568,
# 		"mktCap": 2794144143933,
# 		"lastDiv": 0.96,
# 		"range": "124.17-198.23",
# 		"changes": -0.13,
# 		"companyName": "Apple Inc.",
# 		"currency": "USD",
# 		"cik": "0000320193",
# 		"isin": "US0378331005",
# 		"cusip": "037833100",
# 		"exchange": "NASDAQ Global Select",
# 		"exchangeShortName": "NASDAQ",
# 		"industry": "Consumer Electronics",
# 		"website": "https://www.apple.com",
# 		"description": "Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; AirPods Max, an over-ear wireless headphone; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, and iPod touch. Further, it provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.",
# 		"ceo": "Mr. Timothy D. Cook",
# 		"sector": "Technology",
# 		"country": "US",
# 		"fullTimeEmployees": "164000",
# 		"phone": "408 996 1010",
# 		"address": "One Apple Park Way",
# 		"city": "Cupertino",
# 		"state": "CA",
# 		"zip": "95014",
# 		"dcfDiff": 4.15176,
# 		"dcf": 150.082,
# 		"image": "https://financialmodelingprep.com/image-stock/AAPL.png",
# 		"ipoDate": "1980-12-12",
# 		"defaultImage": false,
# 		"isEtf": false,
# 		"isActivelyTrading": true,
# 		"isAdr": false,
# 		"isFund": false
# 	}
# ]

# %% [markdown]
# ### 3.3. Retrieve Key Metrics - get_key_metrics_ttm

# %%
def get_key_metrics_ttm(symbol):
  """
  Get key financial metrics for a company, including revenue, net income, and price-to-earnings ratio (P/E ratio). Assess a company's financial performance and compare it to its competitors.
  """
  url = f"https://financialmodelingprep.com/api/v3/key-metrics-ttm/{symbol}?apikey={FMP_API_KEY}"
  response = requests.get(url)
  data = response.json()
  try:
    results = data[0]
    key_metrics = {
    "revenuePerShareTTM": results["revenuePerShareTTM"],
    "netIncomePerShareTTM": results["netIncomePerShareTTM"],
    "operatingCashFlowPerShareTTM": results["operatingCashFlowPerShareTTM"],
    "freeCashFlowPerShareTTM": results["freeCashFlowPerShareTTM"],
    "cashPerShareTTM": results["cashPerShareTTM"],
    "bookValuePerShareTTM": results["bookValuePerShareTTM"],
    "tangibleBookValuePerShareTTM": results["tangibleBookValuePerShareTTM"],
    "marketCapTTM": results["marketCapTTM"],
    "enterpriseValueTTM": results["enterpriseValueTTM"],
    "peRatioTTM": results["peRatioTTM"],
    "priceToSalesRatioTTM": results["priceToSalesRatioTTM"],
    "priceToFCFRatioTTM": results["pfcfRatioTTM"],
    "priceToBookRatioTTM": results["ptbRatioTTM"],
    "evToSalesTTM": results["evToSalesTTM"],
    "enterpriseValueOverEBITDATTM": results["enterpriseValueOverEBITDATTM"],
    "evToOperatingCashFlowTTM": results["evToOperatingCashFlowTTM"],
    "evToFreeCashFlowTTM": results["evToFreeCashFlowTTM"],
    "earningsYieldTTM": results["earningsYieldTTM"],
    "freeCashFlowYieldTTM": results["freeCashFlowYieldTTM"],
    "debtToEquityTTM": results["debtToEquityTTM"],
    "debtToAssetsTTM": results["debtToAssetsTTM"],
    "netDebtToEBITDATTM": results["netDebtToEBITDATTM"],
    "currentRatioTTM": results["currentRatioTTM"],
    "interestCoverageTTM": results["interestCoverageTTM"],
    "roicTTM": results["roicTTM"],
    }
    return key_metrics
  except (IndexError, KeyError):
    return {"error": f"Invalid symbol or data not available for {symbol}"}


## Format follows:
# [
# 	{
# 		"revenuePerShareTTM": 24.458048210384074,
# 		"netIncomePerShareTTM": 6.036586197112504,
# 		"operatingCashFlowPerShareTTM": 7.203132909243405,
# 		"freeCashFlowPerShareTTM": 6.433270686869992,
# 		"cashPerShareTTM": 3.980350134740222,
# 		"bookValuePerShareTTM": 3.8396918155842026,
# 		"tangibleBookValuePerShareTTM": 3.8396918155842026,
# 		"shareholdersEquityPerShareTTM": 3.8396918155842026,
# 		"interestDebtPerShareTTM": 7.200966974981038,
# 		"marketCapTTM": 2767892759466,
# 		"enterpriseValueTTM": 2848764759466,
# 		"peRatioTTM": 29.32798343618193,
# 		"priceToSalesRatioTTM": 7.209311935848182,
# 		"pocfratioTTM": 24.578319216186145,
# 		"pfcfRatioTTM": 27.40840662130769,
# 		"pbRatioTTM": 46.10810150998109,
# 		"ptbRatioTTM": 46.10810150998109,
# 		"evToSalesTTM": 7.4199528549668825,
# 		"enterpriseValueOverEBITDATTM": 23.562009507183326,
# 		"evToOperatingCashFlowTTM": 25.194254629492715,
# 		"evToFreeCashFlowTTM": 28.20922256791468,
# 		"earningsYieldTTM": 0.03409712782251166,
# 		"freeCashFlowYieldTTM": 0.0364851563177914,
# 		"debtToEquityTTM": 1.8130537213392175,
# 		"debtToAssetsTTM": 0.32617195661387666,
# 		"netDebtToEBITDATTM": 0.6688887969893719,
# 		"currentRatioTTM": 0.9815625425125837,
# 		"interestCoverageTTM": 29.863225119744545,
# 		"incomeQualityTTM": 1.1932460953989026,
# 		"dividendYieldTTM": 0.005309507577062701,
# 		"dividendYieldPercentageTTM": 0.5309507577062702,
# 		"payoutRatioTTM": 0.15797804981004643,
# 		"salesGeneralAndAdministrativeToRevenueTTM": 0,
# 		"researchAndDevelopementToRevenueTTM": 0.07649511763771283,
# 		"intangiblesToTotalAssetsTTM": 0,
# 		"capexToOperatingCashFlowTTM": -0.10687880288665629,
# 		"capexToRevenueTTM": -0.03147684622056453,
# 		"capexToDepreciationTTM": -1.030176455545137,
# 		"stockBasedCompensationToRevenueTTM": 0.027312057051620986,
# 		"grahamNumberTTM": 22.83679462709757,
# 		"roicTTM": 0.5630471938175102,
# 		"returnOnTangibleAssetsTTM": 0.2828335890257225,
# 		"grahamNetNetTTM": -11.416830608779144,
# 		"workingCapitalTTM": -2304000000,
# 		"tangibleAssetValueTTM": 60274000000,
# 		"netCurrentAssetValueTTM": -152105000000,
# 		"investedCapitalTTM": 1.8130537213392175,
# 		"averageReceivablesTTM": 37542500000,
# 		"averagePayablesTTM": 44822000000,
# 		"averageInventoryTTM": 7416500000,
# 		"daysSalesOutstandingTTM": 37.25360935371536,
# 		"daysPayablesOutstandingTTM": 78.5066807297448,
# 		"daysOfInventoryOnHandTTM": 12.357922226265103,
# 		"receivablesTurnoverTTM": 9.79770836523248,
# 		"payablesTurnoverTTM": 4.649285851945438,
# 		"inventoryTurnoverTTM": 29.535709427288804,
# 		"roeTTM": 1.649211812157629,
# 		"capexPerShareTTM": -0.769862222373413,
# 		"dividendPerShareTTM": 0.94,
# 		"debtToMarketCapTTM": 0.03948129840878771
# 	}
# ]

# %% [markdown]
# ### 3.4. Get Financial Statements: Income Statement - get_income_statement

# %%
def get_income_statement(symbol):
  """
  Fetch last income statement for the given company symbol such as revenue,␣
  gross profit, net income, EBITDA, EPS.
  """
  url = f"https://financialmodelingprep.com/api/v3/income-statement/{symbol}?period=annual&apikey={FMP_API_KEY}"
  response = requests.get(url)
  data = response.json()
  try:
    results = data[0]
    financials = {
      "date": results["date"],
      "revenue": results["revenue"],
      "gross profit": results["grossProfit"],
      "net Income": results["netIncome"],
      "ebitda": results["ebitda"],
      "EPS": results["eps"],
      "EPS diluted":results["epsdiluted"]
    }
    return data, financials
  except (IndexError, KeyError):
    return {"error": f"Could not fetch financials for symbol: {symbol}"}

## Data provided by the Income Statement endpoint follows the following fomrat:
# [
# 	{
# 		"date": "2022-09-24",
# 		"symbol": "AAPL",
# 		"reportedCurrency": "USD",
# 		"cik": "0000320193",
# 		"fillingDate": "2022-10-28",
# 		"acceptedDate": "2022-10-27 18:01:14",
# 		"calendarYear": "2022",
# 		"period": "FY",
# 		"revenue": 394328000000,
# 		"costOfRevenue": 223546000000,
# 		"grossProfit": 170782000000,
# 		"grossProfitRatio": 0.4330963056,
# 		"researchAndDevelopmentExpenses": 26251000000,
# 		"generalAndAdministrativeExpenses": 0,
# 		"sellingAndMarketingExpenses": 0,
# 		"sellingGeneralAndAdministrativeExpenses": 25094000000,
# 		"otherExpenses": -334000000,
# 		"operatingExpenses": 51345000000,
# 		"costAndExpenses": 274891000000,
# 		"interestIncome": 2825000000,
# 		"interestExpense": 2931000000,
# 		"depreciationAndAmortization": 11104000000,
# 		"ebitda": 130541000000,
# 		"ebitdaratio": 0.3310467428,
# 		"operatingIncome": 119437000000,
# 		"operatingIncomeRatio": 0.302887444,
# 		"totalOtherIncomeExpensesNet": -334000000,
# 		"incomeBeforeTax": 119103000000,
# 		"incomeBeforeTaxRatio": 0.3020404333,
# 		"incomeTaxExpense": 19300000000,
# 		"netIncome": 99803000000,
# 		"netIncomeRatio": 0.2530964071,
# 		"eps": 6.15,
# 		"epsdiluted": 6.11,
# 		"weightedAverageShsOut": 16215963000,
# 		"weightedAverageShsOutDil": 16325819000,
# 		"link": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm",
# 		"finalLink": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm"
# 	}
# ]

# %% [markdown]
# ### 3.5. Retrieve Senate Trades - get_senate_trades

# %%
def get_senate_trades(symbol):
  """
  Track the trading activity of US Senators and identify potential conflicts of interest. This endpoint provides a list of all the trades that have been made by US Senators, including the date of the trade, the asset traded, the amount traded, and the price per share.
  """
  url = f"https://financialmodelingprep.com/api/v4/senate-trading?symbol={symbol}&apikey={FMP_API_KEY}"
  response = requests.get(url)
  data = response.json()
  try:
    results = data[0]
    senate_trades = {
    "symbol": results["symbol"],
    "assetName": results["assetDescription"],
    "assetType": results["assetType"],
    "firstName": results["firstName"],
    "lastName": results["lastName"],
    "office": results["office"],
    "link": results["link"],
    "date": results["dateRecieved"],
    "transactionDate": results["transactionDate"],
    "owner": results["owner"],
    "type": results["type"],
    "amount": results["amount"],
    "comment": results["comment"],
    }
    return senate_trades
  except (IndexError, KeyError):
    return {"error": f"Invalid symbol or data not available for {symbol}"}


## Format of the endpoint output:
# [
# 	{
# 		"firstName": "Daniel S",
# 		"lastName": "Sullivan",
# 		"office": "Sullivan, Dan (Senator)",
# 		"link": "https://efdsearch.senate.gov/search/view/ptr/f9252211-a695-4c37-869a-0e223fce8d88/",
# 		"dateRecieved": "2023-09-21",
# 		"transactionDate": "2023-08-22",
# 		"owner": "Joint",
# 		"assetDescription": "Apple Inc",
# 		"assetType": "Stock",
# 		"type": "Sale (Full)",
# 		"amount": "$15,001 - $50,000",
# 		"comment": "Sale part of investment strategy of 3rd party investment professional to exchange individual stocks received after death of filer’s parents for EIFs.",
# 		"symbol": "AAPL"
# 	}
# ]

# %% [markdown]
# ### 3.6. Retrieve House of Reps Trades - get_house_trades

# %%
def get_house_trades(symbol):
  """
  Track the trading activity of US Senators and identify potential conflicts of interest. This endpoint provides a list of all the trades that have been made by US Senators, including the date of the trade, the asset traded, the amount traded, and the price per share.
  """
  url = f"https://financialmodelingprep.com/api/v4/senate-disclosure?symbol={symbol}&apikey={FMP_API_KEY}"
  response = requests.get(url)
  data = response.json()
  try:
    results = data[0]
    house_trades = {
    "ticker": results["ticker"],
    "assetName": results["assetDescription"],
    "representative": results["representative"],
    "district": results["district"],
    "link": results["link"],
    "date": results["disclosureDate"],
    "transactionDate": results["transactionDate"],
    "owner": results["owner"],
    "type": results["type"],
    "amount": results["amount"],
    "capitalGainsOver200USD": results["capitalGainsOver200USD"],
    }
    return house_trades
  except (IndexError, KeyError):
    return {"error": f"Invalid symbol or data not available for {symbol}"}


## Format of the endpoint output:
# [
# 	{
# 		"disclosureYear": "2023",
# 		"disclosureDate": "2023-08-23",
# 		"transactionDate": "2023-08-07",
# 		"owner": "self",
# 		"ticker": "AAPL",
# 		"assetDescription": "Apple Inc.",
# 		"type": "purchase",
# 		"amount": "$1,001 - $15,000",
# 		"representative": "Michael Patrick Guest",
# 		"district": "MS03",
# 		"link": "https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2023/20023442.pdf",
# 		"capitalGainsOver200USD": "False"
# 	}
# ]

# %% [markdown]
# ### 3.5 Test Tools and Functions

# %%
get_stock_price("TSLA")
# Out:
# {'symbol': 'TSLA',
#  'price': 219.16,
#  'volume': 85123635,
#  'avgVolume': 85236089,
#  'priceAvg50': 225.3062,
#  'priceAvg200': 202.33635,
#  'EPS': 3.55,
#  'PE': 61.74,
#  'earningsAnnouncement': '2024-10-23T00:00:00.000+0000'}

# %%
get_company_financials("MPC")
# Out:
# {'symbol': 'MPC',
#  'companyName': 'Marathon Petroleum Corporation',
#  'marketCap': 54386150000,
#  'industry': 'Oil & Gas Refining & Marketing',
#  'sector': 'Energy',
#  'website': 'https://www.marathonpetroleum.com',
#  'beta': 1.358,
#  'price': 162.5}

# %%
get_income_statement("NVDA")
# Out:
# ([{'date': '2024-01-28',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2024-02-21',
#    'acceptedDate': '2024-02-21 16:36:57',
#    'calendarYear': '2024',
#    'period': 'FY',
#    'revenue': 60922000000,
#    'costOfRevenue': 16621000000,
#    'grossProfit': 44301000000,
#    'grossProfitRatio': 0.7271757329,
#    'researchAndDevelopmentExpenses': 8675000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 2654000000,
#    'otherExpenses': 237000000,
#    'operatingExpenses': 11329000000,
#    'costAndExpenses': 27950000000,
#    'interestIncome': 866000000,
#    'interestExpense': 257000000,
#    'depreciationAndAmortization': 1508000000,
#    'ebitda': 35583000000,
#    'ebitdaratio': 0.5840747185,
#    'operatingIncome': 32972000000,
#    'operatingIncomeRatio': 0.5412166377,
#    'totalOtherIncomeExpensesNet': 237000000,
#    'incomeBeforeTax': 33818000000,
#    'incomeBeforeTaxRatio': 0.5551032468,
#    'incomeTaxExpense': 4058000000,
#    'netIncome': 29760000000,
#    'netIncomeRatio': 0.4884934835,
#    'eps': 1.21,
#    'epsdiluted': 1.19,
#    'weightedAverageShsOut': 24690000000,
#    'weightedAverageShsOutDil': 24940000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm'},
#   {'date': '2023-01-29',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2023-02-24',
#    'acceptedDate': '2023-02-24 17:23:43',
#    'calendarYear': '2023',
#    'period': 'FY',
#    'revenue': 26974000000,
#    'costOfRevenue': 11618000000,
#    'grossProfit': 15356000000,
#    'grossProfitRatio': 0.5692889449,
#    'researchAndDevelopmentExpenses': 7339000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 2440000000,
#    'otherExpenses': -48000000,
#    'operatingExpenses': 9779000000,
#    'costAndExpenses': 21397000000,
#    'interestIncome': 267000000,
#    'interestExpense': 262000000,
#    'depreciationAndAmortization': 1544000000,
#    'ebitda': 7340000000,
#    'ebitdaratio': 0.2721138874,
#    'operatingIncome': 4224000000,
#    'operatingIncomeRatio': 0.1565952399,
#    'totalOtherIncomeExpensesNet': -1401000000,
#    'incomeBeforeTax': 4181000000,
#    'incomeBeforeTaxRatio': 0.1550011122,
#    'incomeTaxExpense': -187000000,
#    'netIncome': 4368000000,
#    'netIncomeRatio': 0.1619337139,
#    'eps': 0.18,
#    'epsdiluted': 0.17,
#    'weightedAverageShsOut': 24870000000,
#    'weightedAverageShsOutDil': 25070000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/0001045810-23-000017-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129.htm'},
#   {'date': '2022-01-30',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2022-03-18',
#    'acceptedDate': '2022-03-17 20:33:34',
#    'calendarYear': '2022',
#    'period': 'FY',
#    'revenue': 26914000000,
#    'costOfRevenue': 9439000000,
#    'grossProfit': 17475000000,
#    'grossProfitRatio': 0.6492903322,
#    'researchAndDevelopmentExpenses': 5268000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 2166000000,
#    'otherExpenses': 107000000,
#    'operatingExpenses': 7434000000,
#    'costAndExpenses': 16873000000,
#    'interestIncome': 29000000,
#    'interestExpense': 236000000,
#    'depreciationAndAmortization': 1174000000,
#    'ebitda': 11351000000,
#    'ebitdaratio': 0.4217507617,
#    'operatingIncome': 10041000000,
#    'operatingIncomeRatio': 0.3730772089,
#    'totalOtherIncomeExpensesNet': -100000000,
#    'incomeBeforeTax': 9941000000,
#    'incomeBeforeTaxRatio': 0.3693616705,
#    'incomeTaxExpense': 189000000,
#    'netIncome': 9752000000,
#    'netIncomeRatio': 0.362339303,
#    'eps': 0.39,
#    'epsdiluted': 0.39,
#    'weightedAverageShsOut': 24960000000,
#    'weightedAverageShsOutDil': 25350000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.htm'},
#   {'date': '2021-01-31',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2021-02-26',
#    'acceptedDate': '2021-02-26 17:03:14',
#    'calendarYear': '2021',
#    'period': 'FY',
#    'revenue': 16675000000,
#    'costOfRevenue': 6279000000,
#    'grossProfit': 10396000000,
#    'grossProfitRatio': 0.6234482759,
#    'researchAndDevelopmentExpenses': 3924000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 1940000000,
#    'otherExpenses': 4000000,
#    'operatingExpenses': 5864000000,
#    'costAndExpenses': 12143000000,
#    'interestIncome': 57000000,
#    'interestExpense': 184000000,
#    'depreciationAndAmortization': 1098000000,
#    'ebitda': 5691000000,
#    'ebitdaratio': 0.3412893553,
#    'operatingIncome': 4532000000,
#    'operatingIncomeRatio': 0.2717841079,
#    'totalOtherIncomeExpensesNet': -123000000,
#    'incomeBeforeTax': 4409000000,
#    'incomeBeforeTaxRatio': 0.2644077961,
#    'incomeTaxExpense': 77000000,
#    'netIncome': 4332000000,
#    'netIncomeRatio': 0.2597901049,
#    'eps': 0.18,
#    'epsdiluted': 0.17,
#    'weightedAverageShsOut': 24680000000,
#    'weightedAverageShsOutDil': 25120000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/0001045810-21-000010-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131.htm'},
#   {'date': '2020-01-26',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2020-02-20',
#    'acceptedDate': '2020-02-20 16:38:18',
#    'calendarYear': '2020',
#    'period': 'FY',
#    'revenue': 10918000000,
#    'costOfRevenue': 4150000000,
#    'grossProfit': 6768000000,
#    'grossProfitRatio': 0.6198937534,
#    'researchAndDevelopmentExpenses': 2829000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 1093000000,
#    'otherExpenses': -2000000,
#    'operatingExpenses': 3922000000,
#    'costAndExpenses': 8072000000,
#    'interestIncome': 178000000,
#    'interestExpense': 52000000,
#    'depreciationAndAmortization': 381000000,
#    'ebitda': 3403000000,
#    'ebitdaratio': 0.3116871222,
#    'operatingIncome': 2846000000,
#    'operatingIncomeRatio': 0.2606704525,
#    'totalOtherIncomeExpensesNet': 124000000,
#    'incomeBeforeTax': 2970000000,
#    'incomeBeforeTaxRatio': 0.2720278439,
#    'incomeTaxExpense': 174000000,
#    'netIncome': 2796000000,
#    'netIncomeRatio': 0.2560908591,
#    'eps': 0.12,
#    'epsdiluted': 0.11,
#    'weightedAverageShsOut': 24360000000,
#    'weightedAverageShsOutDil': 24720000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/0001045810-20-000010-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-2020x10k.htm'},
#   {'date': '2019-01-27',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2019-02-21',
#    'acceptedDate': '2019-02-21 16:37:18',
#    'calendarYear': '2019',
#    'period': 'FY',
#    'revenue': 11716000000,
#    'costOfRevenue': 4545000000,
#    'grossProfit': 7171000000,
#    'grossProfitRatio': 0.6120689655,
#    'researchAndDevelopmentExpenses': 2376000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 991000000,
#    'otherExpenses': 14000000,
#    'operatingExpenses': 3367000000,
#    'costAndExpenses': 7912000000,
#    'interestIncome': 136000000,
#    'interestExpense': 58000000,
#    'depreciationAndAmortization': 262000000,
#    'ebitda': 3954000000,
#    'ebitdaratio': 0.337487197,
#    'operatingIncome': 3804000000,
#    'operatingIncomeRatio': 0.3246841926,
#    'totalOtherIncomeExpensesNet': 14000000,
#    'incomeBeforeTax': 3896000000,
#    'incomeBeforeTaxRatio': 0.3325367019,
#    'incomeTaxExpense': -245000000,
#    'netIncome': 4141000000,
#    'netIncomeRatio': 0.3534482759,
#    'eps': 0.17,
#    'epsdiluted': 0.17,
#    'weightedAverageShsOut': 24320000000,
#    'weightedAverageShsOutDil': 25000000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/0001045810-19-000023-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/nvda-2019x10k.htm'},
#   {'date': '2018-01-28',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2018-02-28',
#    'acceptedDate': '2018-02-28 16:31:19',
#    'calendarYear': '2018',
#    'period': 'FY',
#    'revenue': 9714000000,
#    'costOfRevenue': 3892000000,
#    'grossProfit': 5822000000,
#    'grossProfitRatio': 0.5993411571,
#    'researchAndDevelopmentExpenses': 1797000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 815000000,
#    'otherExpenses': -22000000,
#    'operatingExpenses': 2612000000,
#    'costAndExpenses': 6504000000,
#    'interestIncome': 69000000,
#    'interestExpense': 61000000,
#    'depreciationAndAmortization': 199000000,
#    'ebitda': 3257000000,
#    'ebitdaratio': 0.3352892732,
#    'operatingIncome': 3210000000,
#    'operatingIncomeRatio': 0.3304508956,
#    'totalOtherIncomeExpensesNet': -22000000,
#    'incomeBeforeTax': 3196000000,
#    'incomeBeforeTaxRatio': 0.3290096768,
#    'incomeTaxExpense': 149000000,
#    'netIncome': 3047000000,
#    'netIncomeRatio': 0.3136709903,
#    'eps': 0.13,
#    'epsdiluted': 0.12,
#    'weightedAverageShsOut': 23960000000,
#    'weightedAverageShsOutDil': 25280000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/0001045810-18-000010-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/nvda-2018x10k.htm'},
#   {'date': '2017-01-29',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2017-03-01',
#    'acceptedDate': '2017-03-01 17:30:49',
#    'calendarYear': '2017',
#    'period': 'FY',
#    'revenue': 6910000000,
#    'costOfRevenue': 2847000000,
#    'grossProfit': 4063000000,
#    'grossProfitRatio': 0.5879884226,
#    'researchAndDevelopmentExpenses': 1463000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 663000000,
#    'otherExpenses': -25000000,
#    'operatingExpenses': 2126000000,
#    'costAndExpenses': 4973000000,
#    'interestIncome': 54000000,
#    'interestExpense': 58000000,
#    'depreciationAndAmortization': 187000000,
#    'ebitda': 1966000000,
#    'ebitdaratio': 0.2845151954,
#    'operatingIncome': 1934000000,
#    'operatingIncomeRatio': 0.2798842258,
#    'totalOtherIncomeExpensesNet': -28000000,
#    'incomeBeforeTax': 1905000000,
#    'incomeBeforeTaxRatio': 0.2756874096,
#    'incomeTaxExpense': 239000000,
#    'netIncome': 1666000000,
#    'netIncomeRatio': 0.2410998553,
#    'eps': 0.077,
#    'epsdiluted': 0.064,
#    'weightedAverageShsOut': 21640000000,
#    'weightedAverageShsOutDil': 25960000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/0001045810-17-000027-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581017000027/nvda-2017x10k.htm'},
#   {'date': '2016-01-31',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2016-03-17',
#    'acceptedDate': '2016-03-16 18:07:18',
#    'calendarYear': '2016',
#    'period': 'FY',
#    'revenue': 5010000000,
#    'costOfRevenue': 2199000000,
#    'grossProfit': 2811000000,
#    'grossProfitRatio': 0.5610778443,
#    'researchAndDevelopmentExpenses': 1331000000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 602000000,
#    'otherExpenses': 4000000,
#    'operatingExpenses': 1933000000,
#    'costAndExpenses': 4132000000,
#    'interestIncome': 39000000,
#    'interestExpense': 47000000,
#    'depreciationAndAmortization': 197000000,
#    'ebitda': 921000000,
#    'ebitdaratio': 0.1838323353,
#    'operatingIncome': 747000000,
#    'operatingIncomeRatio': 0.1491017964,
#    'totalOtherIncomeExpensesNet': -127000000,
#    'incomeBeforeTax': 743000000,
#    'incomeBeforeTaxRatio': 0.1483033932,
#    'incomeTaxExpense': 129000000,
#    'netIncome': 614000000,
#    'netIncomeRatio': 0.1225548902,
#    'eps': 0.028,
#    'epsdiluted': 0.027,
#    'weightedAverageShsOut': 21720000000,
#    'weightedAverageShsOutDil': 22760000000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/0001045810-16-000205-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581016000205/nvda-2016x10k.htm'},
#   {'date': '2015-01-25',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2015-03-12',
#    'acceptedDate': '2015-03-11 19:48:05',
#    'calendarYear': '2015',
#    'period': 'FY',
#    'revenue': 4681507000,
#    'costOfRevenue': 2082030000,
#    'grossProfit': 2599477000,
#    'grossProfitRatio': 0.5552650033,
#    'researchAndDevelopmentExpenses': 1359725000,
#    'generalAndAdministrativeExpenses': 459763000,
#    'sellingAndMarketingExpenses': 21000000,
#    'sellingGeneralAndAdministrativeExpenses': 480763000,
#    'otherExpenses': 13890000,
#    'operatingExpenses': 1840488000,
#    'costAndExpenses': 3922518000,
#    'interestIncome': 28090000,
#    'interestExpense': 46133000,
#    'depreciationAndAmortization': 220125000,
#    'ebitda': 800969000,
#    'ebitdaratio': 0.1710921291,
#    'operatingIncome': 758989000,
#    'operatingIncomeRatio': 0.1621249311,
#    'totalOtherIncomeExpensesNet': 13890000,
#    'incomeBeforeTax': 754836000,
#    'incomeBeforeTaxRatio': 0.1612378236,
#    'incomeTaxExpense': 124249000,
#    'netIncome': 630587000,
#    'netIncomeRatio': 0.1346974382,
#    'eps': 0.028,
#    'epsdiluted': 0.028,
#    'weightedAverageShsOut': 22092760000,
#    'weightedAverageShsOutDil': 22522720000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/0001045810-15-000036-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581015000036/nvda-2015x10k.htm'},
#   {'date': '2014-01-26',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2014-03-13',
#    'acceptedDate': '2014-03-12 19:18:57',
#    'calendarYear': '2014',
#    'period': 'FY',
#    'revenue': 4130162000,
#    'costOfRevenue': 1862399000,
#    'grossProfit': 2267763000,
#    'grossProfitRatio': 0.5490736199,
#    'researchAndDevelopmentExpenses': 1335834000,
#    'generalAndAdministrativeExpenses': 422702000,
#    'sellingAndMarketingExpenses': 13000000,
#    'sellingGeneralAndAdministrativeExpenses': 435702000,
#    'otherExpenses': 7351000,
#    'operatingExpenses': 1771536000,
#    'costAndExpenses': 3633935000,
#    'interestIncome': 17119000,
#    'interestExpense': 10443000,
#    'depreciationAndAmortization': 239148000,
#    'ebitda': 520697000,
#    'ebitdaratio': 0.1260718103,
#    'operatingIncome': 496227000,
#    'operatingIncomeRatio': 0.1201471032,
#    'totalOtherIncomeExpensesNet': 7351000,
#    'incomeBeforeTax': 510254000,
#    'incomeBeforeTaxRatio': 0.123543338,
#    'incomeTaxExpense': 70264000,
#    'netIncome': 439990000,
#    'netIncomeRatio': 0.1065309303,
#    'eps': 0.019,
#    'epsdiluted': 0.019,
#    'weightedAverageShsOut': 23515720000,
#    'weightedAverageShsOutDil': 23780680000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/0001045810-14-000030-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581014000030/nvda-2014x10k.htm'},
#   {'date': '2013-01-27',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2013-03-12',
#    'acceptedDate': '2013-03-12 17:03:06',
#    'calendarYear': '2013',
#    'period': 'FY',
#    'revenue': 4280159000,
#    'costOfRevenue': 2053816000,
#    'grossProfit': 2226343000,
#    'grossProfitRatio': 0.5201542746,
#    'researchAndDevelopmentExpenses': 1147282000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 430822000,
#    'otherExpenses': -2814000,
#    'operatingExpenses': 1578104000,
#    'costAndExpenses': 3631920000,
#    'interestIncome': 19908000,
#    'interestExpense': 3294000,
#    'depreciationAndAmortization': 226235000,
#    'ebitda': 648239000,
#    'ebitdaratio': 0.1514520839,
#    'operatingIncome': 648239000,
#    'operatingIncomeRatio': 0.1514520839,
#    'totalOtherIncomeExpensesNet': -2814000,
#    'incomeBeforeTax': 662039000,
#    'incomeBeforeTaxRatio': 0.1546762632,
#    'incomeTaxExpense': 99503000,
#    'netIncome': 562536000,
#    'netIncomeRatio': 0.1314287623,
#    'eps': 0.023,
#    'epsdiluted': 0.023,
#    'weightedAverageShsOut': 24772960000,
#    'weightedAverageShsOutDil': 24998280000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/0001045810-13-000008-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581013000008/nvda-2013x10k.htm'},
#   {'date': '2012-01-29',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2012-03-13',
#    'acceptedDate': '2012-03-13 16:56:38',
#    'calendarYear': '2012',
#    'period': 'FY',
#    'revenue': 3997930000,
#    'costOfRevenue': 1941413000,
#    'grossProfit': 2056517000,
#    'grossProfitRatio': 0.5143954496,
#    'researchAndDevelopmentExpenses': 1002605000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 405613000,
#    'otherExpenses': -963000,
#    'operatingExpenses': 1408218000,
#    'costAndExpenses': 3349631000,
#    'interestIncome': 19149000,
#    'interestExpense': 3089000,
#    'depreciationAndAmortization': 204205000,
#    'ebitda': 648299000,
#    'ebitdaratio': 0.1621586671,
#    'operatingIncome': 648299000,
#    'operatingIncomeRatio': 0.1621586671,
#    'totalOtherIncomeExpensesNet': -963000,
#    'incomeBeforeTax': 663396000,
#    'incomeBeforeTaxRatio': 0.1659348713,
#    'incomeTaxExpense': 82306000,
#    'netIncome': 581090000,
#    'netIncomeRatio': 0.1453477174,
#    'eps': 0.024,
#    'epsdiluted': 0.024,
#    'weightedAverageShsOut': 24145840000,
#    'weightedAverageShsOutDil': 24654840000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/0001045810-12-000013-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581012000013/nvda-2012x10k.htm'},
#   {'date': '2011-01-30',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2011-03-16',
#    'acceptedDate': '2011-03-16 16:33:51',
#    'calendarYear': '2011',
#    'period': 'FY',
#    'revenue': 3543309000,
#    'costOfRevenue': 2134219000,
#    'grossProfit': 1409090000,
#    'grossProfitRatio': 0.3976762964,
#    'researchAndDevelopmentExpenses': 848830000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 418513000,
#    'otherExpenses': 0,
#    'operatingExpenses': 1153343000,
#    'costAndExpenses': 3287562000,
#    'interestIncome': 19057000,
#    'interestExpense': 3127000,
#    'depreciationAndAmortization': 186989000,
#    'ebitda': 255747000,
#    'ebitdaratio': 0.0721774477,
#    'operatingIncome': 255747000,
#    'operatingIncomeRatio': 0.0721774477,
#    'totalOtherIncomeExpensesNet': -508000,
#    'incomeBeforeTax': 271169000,
#    'incomeBeforeTaxRatio': 0.0765298765,
#    'incomeTaxExpense': 18023000,
#    'netIncome': 253146000,
#    'netIncomeRatio': 0.0714433881,
#    'eps': 0.011,
#    'epsdiluted': 0.011,
#    'weightedAverageShsOut': 23007080000,
#    'weightedAverageShsOutDil': 23547360000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/0001045810-11-000015-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581011000015/fy2011form10k.htm'},
#   {'date': '2010-01-31',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2010-03-18',
#    'acceptedDate': '2010-03-17 19:16:55',
#    'calendarYear': '2010',
#    'period': 'FY',
#    'revenue': 3326445000,
#    'costOfRevenue': 2149522000,
#    'grossProfit': 1176923000,
#    'grossProfitRatio': 0.3538080443,
#    'researchAndDevelopmentExpenses': 908851000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 367017000,
#    'otherExpenses': 0,
#    'operatingExpenses': 1275868000,
#    'costAndExpenses': 3425390000,
#    'interestIncome': 23115000,
#    'interestExpense': 3320000,
#    'depreciationAndAmortization': 196664000,
#    'ebitda': -115596000,
#    'ebitdaratio': -0.0347506121,
#    'operatingIncome': -98945000,
#    'operatingIncomeRatio': -0.029744968,
#    'totalOtherIncomeExpensesNet': 16651000,
#    'incomeBeforeTax': -82294000,
#    'incomeBeforeTaxRatio': -0.0247393238,
#    'incomeTaxExpense': -14307000,
#    'netIncome': -67987000,
#    'netIncomeRatio': -0.0204383358,
#    'eps': -0.0031,
#    'epsdiluted': -0.0031,
#    'weightedAverageShsOut': 21982960000,
#    'weightedAverageShsOutDil': 21982960000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/0001045810-10-000006-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581010000006/fy2010form10k.htm'},
#   {'date': '2009-01-25',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2009-03-13',
#    'acceptedDate': '2009-03-13 09:02:25',
#    'calendarYear': '2009',
#    'period': 'FY',
#    'revenue': 3424859000,
#    'costOfRevenue': 2250590000,
#    'grossProfit': 1174269000,
#    'grossProfitRatio': 0.3428663779,
#    'researchAndDevelopmentExpenses': 855879000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 362222000,
#    'otherExpenses': 26868000,
#    'operatingExpenses': 1218101000,
#    'costAndExpenses': 3468691000,
#    'interestIncome': 42859000,
#    'interestExpense': -406000,
#    'depreciationAndAmortization': 185023000,
#    'ebitda': 182766000,
#    'ebitdaratio': 0.0533645327,
#    'operatingIncome': -70700000,
#    'operatingIncomeRatio': -0.0206431856,
#    'totalOtherIncomeExpensesNet': -41575000,
#    'incomeBeforeTax': -42954000,
#    'incomeBeforeTaxRatio': -0.0125418302,
#    'incomeTaxExpense': -12913000,
#    'netIncome': -30041000,
#    'netIncomeRatio': -0.008771456,
#    'eps': -0.0014,
#    'epsdiluted': -0.0014,
#    'weightedAverageShsOut': 21925040000,
#    'weightedAverageShsOutDil': 21925040000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581009000013/0001045810-09-000013-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581009000013/fy2009form10k.htm'},
#   {'date': '2008-01-31',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2008-01-31',
#    'acceptedDate': '2008-01-30 19:00:00',
#    'calendarYear': '2008',
#    'period': 'FY',
#    'revenue': 4097860000,
#    'costOfRevenue': 2228580000,
#    'grossProfit': 1869280000,
#    'grossProfitRatio': 0.4561600445,
#    'researchAndDevelopmentExpenses': 691637000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 341297000,
#    'otherExpenses': 0,
#    'operatingExpenses': 1032934000,
#    'costAndExpenses': 3261514000,
#    'interestIncome': 0,
#    'interestExpense': 0,
#    'depreciationAndAmortization': 133192000,
#    'ebitda': 968778000,
#    'ebitdaratio': 0.2364107119,
#    'operatingIncome': 836346000,
#    'operatingIncomeRatio': 0.204093356,
#    'totalOtherIncomeExpensesNet': 760000,
#    'incomeBeforeTax': 901341000,
#    'incomeBeforeTaxRatio': 0.2199540736,
#    'incomeTaxExpense': 103696000,
#    'netIncome': 797645000,
#    'netIncomeRatio': 0.1946491583,
#    'eps': 0.036,
#    'epsdiluted': 0.033,
#    'weightedAverageShsOut': 22004320000,
#    'weightedAverageShsOutDil': 24269280000,
#    'link': '',
#    'finalLink': ''},
#   {'date': '2007-01-28',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2007-03-16',
#    'acceptedDate': '2007-03-16 14:12:51',
#    'calendarYear': '2007',
#    'period': 'FY',
#    'revenue': 3068771000,
#    'costOfRevenue': 1768322000,
#    'grossProfit': 1300449000,
#    'grossProfitRatio': 0.4237686683,
#    'researchAndDevelopmentExpenses': 553467000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 293530000,
#    'otherExpenses': 0,
#    'operatingExpenses': 846997000,
#    'costAndExpenses': 2615319000,
#    'interestIncome': 41820000,
#    'interestExpense': -21000,
#    'depreciationAndAmortization': 107562000,
#    'ebitda': 561785000,
#    'ebitdaratio': 0.1830651424,
#    'operatingIncome': 453452000,
#    'operatingIncomeRatio': 0.147763388,
#    'totalOtherIncomeExpensesNet': -771000,
#    'incomeBeforeTax': 494480000,
#    'incomeBeforeTaxRatio': 0.1611329096,
#    'incomeTaxExpense': 46350000,
#    'netIncome': 448834000,
#    'netIncomeRatio': 0.1462585511,
#    'eps': 0.021,
#    'epsdiluted': 0.019,
#    'weightedAverageShsOut': 21133673160,
#    'weightedAverageShsOutDil': 23478500760,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581007000008/0001045810-07-000008-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581007000008/fy2007annualreportonform10-k.htm'},
#   {'date': '2006-01-29',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2006-11-29',
#    'acceptedDate': '2006-11-29 06:11:41',
#    'calendarYear': '2006',
#    'period': 'FY',
#    'revenue': 2375687000,
#    'costOfRevenue': 1464892000,
#    'grossProfit': 910795000,
#    'grossProfitRatio': 0.3833817334,
#    'researchAndDevelopmentExpenses': 352099000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 204441000,
#    'otherExpenses': 14158000,
#    'operatingExpenses': 570698000,
#    'costAndExpenses': 2035590000,
#    'interestIncome': 20698000,
#    'interestExpense': -72000,
#    'depreciationAndAmortization': 97977000,
#    'ebitda': 452734000,
#    'ebitdaratio': 0.1905697173,
#    'operatingIncome': 340097000,
#    'operatingIncomeRatio': 0.1431573267,
#    'totalOtherIncomeExpensesNet': -14660000,
#    'incomeBeforeTax': 360221000,
#    'incomeBeforeTaxRatio': 0.1516281396,
#    'incomeTaxExpense': 57635000,
#    'netIncome': 302586000,
#    'netIncomeRatio': 0.1273677888,
#    'eps': 0.015,
#    'epsdiluted': 0.014,
#    'weightedAverageShsOut': 20352623680,
#    'weightedAverageShsOutDil': 21931274360,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000119312506243224/0001193125-06-243224-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000119312506243224/d10ka.htm'},
#   {'date': '2005-01-30',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2005-03-22',
#    'acceptedDate': '2005-03-22 14:33:30',
#    'calendarYear': '2005',
#    'period': 'FY',
#    'revenue': 2010033000,
#    'costOfRevenue': 1360547000,
#    'grossProfit': 649486000,
#    'grossProfitRatio': 0.3231220582,
#    'researchAndDevelopmentExpenses': 335104000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 200789000,
#    'otherExpenses': 0,
#    'operatingExpenses': 535893000,
#    'costAndExpenses': 1896440000,
#    'interestIncome': 11422000,
#    'interestExpense': -164000,
#    'depreciationAndAmortization': 102597000,
#    'ebitda': 215596000,
#    'ebitdaratio': 0.1072599306,
#    'operatingIncome': 113593000,
#    'operatingIncomeRatio': 0.0565130025,
#    'totalOtherIncomeExpensesNet': 594000,
#    'incomeBeforeTax': 125445000,
#    'incomeBeforeTaxRatio': 0.0624094231,
#    'incomeTaxExpense': 25089000,
#    'netIncome': 100356000,
#    'netIncomeRatio': 0.0499275385,
#    'eps': 0.0045,
#    'epsdiluted': 0.0042,
#    'weightedAverageShsOut': 19917481240,
#    'weightedAverageShsOutDil': 21176371800,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581005000008/0001045810-05-000008-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581005000008/annualreport.htm'},
#   {'date': '2004-01-25',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2004-03-29',
#    'acceptedDate': '2004-03-29 12:31:52',
#    'calendarYear': '2004',
#    'period': 'FY',
#    'revenue': 1822945000,
#    'costOfRevenue': 1294067000,
#    'grossProfit': 528878000,
#    'grossProfitRatio': 0.2901228507,
#    'researchAndDevelopmentExpenses': 269972000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 165249000,
#    'otherExpenses': 3500000,
#    'operatingExpenses': 435221000,
#    'costAndExpenses': 1729288000,
#    'interestIncome': 18561000,
#    'interestExpense': -12010000,
#    'depreciationAndAmortization': 82688000,
#    'ebitda': 189880000,
#    'ebitdaratio': 0.1041611239,
#    'operatingIncome': 90157000,
#    'operatingIncomeRatio': 0.0494567856,
#    'totalOtherIncomeExpensesNet': -13535000,
#    'incomeBeforeTax': 86673000,
#    'incomeBeforeTaxRatio': 0.0475455924,
#    'incomeTaxExpense': 12254000,
#    'netIncome': 74419000,
#    'netIncomeRatio': 0.0408235026,
#    'eps': 0.0038,
#    'epsdiluted': 0.0036,
#    'weightedAverageShsOut': 19301229400,
#    'weightedAverageShsOutDil': 20714482760,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581004000007/0001045810-04-000007-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581004000007/annualreport.htm'},
#   {'date': '2003-01-26',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2003-04-25',
#    'acceptedDate': '2003-04-24 21:55:57',
#    'calendarYear': '2003',
#    'period': 'FY',
#    'revenue': 1909447000,
#    'costOfRevenue': 1333435000,
#    'grossProfit': 576012000,
#    'grossProfitRatio': 0.3016643039,
#    'researchAndDevelopmentExpenses': 224873000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 207153000,
#    'otherExpenses': 55668000,
#    'operatingExpenses': 432026000,
#    'costAndExpenses': 1765461000,
#    'interestIncome': 0,
#    'interestExpense': 0,
#    'depreciationAndAmortization': 58216000,
#    'ebitda': 202202000,
#    'ebitdaratio': 0.1058955813,
#    'operatingIncome': 143986000,
#    'operatingIncomeRatio': 0.0754071729,
#    'totalOtherIncomeExpensesNet': 6571000,
#    'incomeBeforeTax': 150557000,
#    'incomeBeforeTaxRatio': 0.0788484834,
#    'incomeTaxExpense': 59758000,
#    'netIncome': 90799000,
#    'netIncomeRatio': 0.0475525113,
#    'eps': 0.0049,
#    'epsdiluted': 0.0045,
#    'weightedAverageShsOut': 18412353840,
#    'weightedAverageShsOutDil': 20197061480,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104596903001196/0001045969-03-001196-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104596903001196/d10k.htm'},
#   {'date': '2002-01-27',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2002-05-14',
#    'acceptedDate': '2002-05-14 08:11:42',
#    'calendarYear': '2002',
#    'period': 'FY',
#    'revenue': 1369471000,
#    'costOfRevenue': 850233000,
#    'grossProfit': 519238000,
#    'grossProfitRatio': 0.379152242,
#    'researchAndDevelopmentExpenses': 153920000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 97185000,
#    'otherExpenses': 26401000,
#    'operatingExpenses': 267476000,
#    'costAndExpenses': 1117709000,
#    'interestIncome': 0,
#    'interestExpense': 11017000,
#    'depreciationAndAmortization': 43497000,
#    'ebitda': 309667000,
#    'ebitdaratio': 0.2261216192,
#    'operatingIncome': 241732000,
#    'operatingIncomeRatio': 0.1765148733,
#    'totalOtherIncomeExpensesNet': -14408000,
#    'incomeBeforeTax': 252749000,
#    'incomeBeforeTaxRatio': 0.1845595854,
#    'incomeTaxExpense': 75825000,
#    'netIncome': 176924000,
#    'netIncomeRatio': 0.1291914907,
#    'eps': 0.01,
#    'epsdiluted': 0.0086,
#    'weightedAverageShsOut': 17153223400,
#    'weightedAverageShsOutDil': 20518620680,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287002002262/0001012870-02-002262-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287002002262/d10k.htm'},
#   {'date': '2001-01-28',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2001-05-25',
#    'acceptedDate': '2001-05-25 00:00:00',
#    'calendarYear': '2001',
#    'period': 'FY',
#    'revenue': 735264000,
#    'costOfRevenue': 444262000,
#    'grossProfit': 291002000,
#    'grossProfitRatio': 0.3957789311,
#    'researchAndDevelopmentExpenses': 86438000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 58437000,
#    'otherExpenses': 0,
#    'operatingExpenses': 160711000,
#    'costAndExpenses': 604973000,
#    'interestIncome': 0,
#    'interestExpense': 0,
#    'depreciationAndAmortization': 15836000,
#    'ebitda': 146133000,
#    'ebitdaratio': 0.1987490208,
#    'operatingIncome': 130291000,
#    'operatingIncomeRatio': 0.1772030182,
#    'totalOtherIncomeExpensesNet': -6000,
#    'incomeBeforeTax': 146964000,
#    'incomeBeforeTaxRatio': 0.1998792271,
#    'incomeTaxExpense': 47027000,
#    'netIncome': 99937000,
#    'netIncomeRatio': 0.1359198873,
#    'eps': 0.0064,
#    'epsdiluted': 0.0052,
#    'weightedAverageShsOut': 15711904040,
#    'weightedAverageShsOutDil': 19105727120,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287001501023/0001012870-01-501023-index.htm',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287001501023/d10k405a.txt'},
#   {'date': '2000-01-30',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '2000-03-13',
#    'acceptedDate': '2000-03-13 00:00:00',
#    'calendarYear': '2000',
#    'period': 'FY',
#    'revenue': 374500000,
#    'costOfRevenue': 225900000,
#    'grossProfit': 148600000,
#    'grossProfitRatio': 0.3967957276,
#    'researchAndDevelopmentExpenses': 47400000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 37100000,
#    'otherExpenses': 0,
#    'operatingExpenses': 94200000,
#    'costAndExpenses': 320100000,
#    'interestIncome': 0,
#    'interestExpense': 0,
#    'depreciationAndAmortization': 9700000,
#    'ebitda': 64100000,
#    'ebitdaratio': 0.1711615487,
#    'operatingIncome': 54400000,
#    'operatingIncomeRatio': 0.1452603471,
#    'totalOtherIncomeExpensesNet': 1800000,
#    'incomeBeforeTax': 56200000,
#    'incomeBeforeTaxRatio': 0.1500667557,
#    'incomeTaxExpense': 18100000,
#    'netIncome': 38100000,
#    'netIncomeRatio': 0.1017356475,
#    'eps': 0.0027,
#    'epsdiluted': 0.0022,
#    'weightedAverageShsOut': 14331394320,
#    'weightedAverageShsOutDil': 17318380800,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287000001346/0001012870-00-001346-index.html',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000101287000001346/'},
#   {'date': '1999-01-31',
#    'symbol': 'NVDA',
#    'reportedCurrency': 'USD',
#    'cik': '0001045810',
#    'fillingDate': '1999-04-29',
#    'acceptedDate': '1999-04-29 00:00:00',
#    'calendarYear': '1999',
#    'period': 'FY',
#    'revenue': 151400000,
#    'costOfRevenue': 103200000,
#    'grossProfit': 48200000,
#    'grossProfitRatio': 0.3183619551,
#    'researchAndDevelopmentExpenses': 25100000,
#    'generalAndAdministrativeExpenses': 0,
#    'sellingAndMarketingExpenses': 0,
#    'sellingGeneralAndAdministrativeExpenses': 18900000,
#    'otherExpenses': 0,
#    'operatingExpenses': 50500000,
#    'costAndExpenses': 153700000,
#    'interestIncome': 0,
#    'interestExpense': 0,
#    'depreciationAndAmortization': 6500000,
#    'ebitda': -2600000,
#    'ebitdaratio': -0.0171730515,
#    'operatingIncome': -2300000,
#    'operatingIncomeRatio': -0.0151915456,
#    'totalOtherIncomeExpensesNet': 6800000,
#    'incomeBeforeTax': 4500000,
#    'incomeBeforeTaxRatio': 0.0297225892,
#    'incomeTaxExpense': 400000,
#    'netIncome': 4100000,
#    'netIncomeRatio': 0.0270805812,
#    'eps': 0.0006,
#    'epsdiluted': 0.0003,
#    'weightedAverageShsOut': 6991200000,
#    'weightedAverageShsOutDil': 13148640000,
#    'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000092962499000772/0000929624-99-000772-index.html',
#    'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/'}],
#  {'date': '2024-01-28',
#   'revenue': 60922000000,
#   'gross profit': 44301000000,
#   'net Income': 29760000000,
#   'ebitda': 35583000000,
#   'EPS': 1.21,
#   'EPS diluted': 1.19})

# %%
get_senate_trades("AMD")
# Out:
# {'symbol': 'AMD',
#  'assetName': 'Advanced Micro Devices Inc',
#  'assetType': 'Stock',
#  'firstName': 'Tommy',
#  'lastName': 'Tuberville',
#  'office': 'Tommy Tuberville',
#  'link': 'https://efdsearch.senate.gov/search/view/ptr/3dabcae6-b7fd-4dd0-9ece-e936d07def11/',
#  'date': '2024-02-14',
#  'transactionDate': '2024-01-19',
#  'owner': 'Joint',
#  'type': 'Sale',
#  'amount': '$15,001 - $50,000',
#  'comment': ''}

# %%
get_house_trades("AMD")
# Out:
# {'ticker': 'AMD',
#  'assetName': 'Advanced Micro Devices, Inc.',
#  'representative': 'Josh Gottheimer',
#  'district': 'NJ05',
#  'link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2024/20025804.pdf',
#  'date': '2024-09-11',
#  'transactionDate': '2024-08-01',
#  'owner': 'Joint',
#  'type': 'Sale (Full)',
#  'amount': '$1,001 - $15,000',
#  'capitalGainsOver200USD': 'False'}

# %%
get_key_metrics_ttm("NVDA")
# Out:
# {'revenuePerShareTTM': 3.918422979900724,
#  'netIncomePerShareTTM': 2.15672552689397,
#  'operatingCashFlowPerShareTTM': 1.9799820978110505,
#  'freeCashFlowPerShareTTM': 1.90357230043128,
#  'cashPerShareTTM': 1.415900398730572,
#  'bookValuePerShareTTM': 2.3662218243958013,
#  'tangibleBookValuePerShareTTM': 2.1394336398405076,
#  'marketCapTTM': 3386857100000,
#  'enterpriseValueTTM': 3388309100000,
#  'peRatioTTM': 64.01834553274978,
#  'priceToSalesRatioTTM': 35.167299365570514,
#  'priceToFCFRatioTTM': 72.39039669986748,
#  'priceToBookRatioTTM': 58.35040425056312,
#  'evToSalesTTM': 35.18237615126626,
#  'enterpriseValueOverEBITDATTM': 53.80488931940166,
#  'evToOperatingCashFlowTTM': 69.62660488245932,
#  'evToFreeCashFlowTTM': 72.42143162484504,
#  'earningsYieldTTM': 0.01562052239366966,
#  'freeCashFlowYieldTTM': 0.013813987014686861,
#  'debtToEquityTTM': 0.14978420482487062,
#  'debtToAssetsTTM': 0.10220939373672662,
#  'netDebtToEBITDATTM': 0.023057134690507193,
#  'currentRatioTTM': 4.268952680936359,
#  'interestCoverageTTM': 237.3784860557769,
#  'roicTTM': 0.7727654750450306}

# %% [markdown]
# ## 4. Create Agentic Flow

# %% [markdown]
# ### 4.1 Convert Functions to Tools for LLM Use

# %%
stock_price_tool = FunctionTool.from_defaults(fn=get_stock_price)
company_financials_tool = FunctionTool.from_defaults(fn=get_company_financials)
key_metrics_ttm_tool = FunctionTool.from_defaults(fn=get_key_metrics_ttm)
senate_trades_tool = FunctionTool.from_defaults(fn=get_senate_trades)
tool_income_statement = FunctionTool.from_defaults(fn=get_income_statement)

# %% [markdown]
# ### 4.2 Create an Anthropic Claude Agent

# %%
from llama_index.core.agent import FunctionCallingAgent

claude_agent = FunctionCallingAgent.from_tools(
    [stock_price_tool, key_metrics_ttm_tool, tool_income_statement],
    llm=anthropic_llm,
    verbose=True,
    allow_parallel_tool_calls=True,
)

# %% [markdown]
# ### 4.3 Create an OpenAI Agent (using o1 mini Reasoning)

# %%
from llama_index.core.agent import FunctionCallingAgent

oai_agent = FunctionCallingAgent.from_tools(
    [stock_price_tool, company_financials_tool, key_metrics_ttm_tool, tool_income_statement],
    llm=openai_llm,
    verbose=True,
    allow_parallel_tool_calls=True,
)

# %% [markdown]
# # Chat with an Agent

# %%
query= "Give me the current price of MPC"
response = claude_agent.chat(query)
print(str(response))
# Out:
# > Running step cb304ba8-585e-4bff-a9aa-887ff01810f2. Step input: Give me the current price of MPC
# Added user message to memory: Give me the current price of MPC
# === LLM Response ===
# Certainly! I'll fetch the current stock price for MPC (Marathon Petroleum Corporation) using the get_stock_price function. This will provide us with the current price and some additional useful information about the stock.
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "MPC"}
# === Function Output ===
# {'symbol': 'MPC', 'price': 162.5, 'volume': 1362630, 'avgVolume': 2703448, 'priceAvg50': 168.6334, 'priceAvg200': 174.57056, 'EPS': 19.07, 'PE': 8.52, 'earningsAnnouncement': '2024-11-05T13:30:00.000+0000'}
# > Running step 702bcafb-562c-42ec-9fd4-d8d3f01ab29d. Step input: None
# === LLM Response ===
# Based on the information retrieved, here's the current price and some additional details for MPC (Marathon Petroleum Corporation):
#
# 1. Current Price: $162.50
# 2. Trading Volume: 1,362,630 shares
# 3. Average 50-day Price: $168.63
# 4. Average 200-day Price: $174.57
# 5. Earnings per Share (EPS): $19.07
# 6. Price-to-Earnings (P/E) Ratio: 8.52
# 7. Next Earnings Announcement: November 5, 2024
#
# The current stock price of MPC is $162.50. It's worth noting that the stock is currently trading below both its 50-day and 200-day moving averages, which might indicate a recent downward trend. The P/E ratio of 8.52 suggests that the stock is relatively inexpensive compared to its earnings, which could be seen as attractive to value investors.
#
# Is there any other information about MPC or its stock performance that you'd like to know?
# Based on the information retrieved, here's the current price and some additional details for MPC (Marathon Petroleum Corporation):
#
# 1. Current Price: $162.50
# 2. Trading Volume: 1,362,630 shares
# 3. Average 50-day Price: $168.63
# 4. Average 200-day Price: $174.57
# 5. Earnings per Share (EPS): $19.07
# 6. Price-to-Earnings (P/E) Ratio: 8.52
# 7. Next Earnings Announcement: November 5, 2024
#
# The current stock price of MPC is $162.50. It's worth noting that the stock is currently trading below both its 50-day and 200-day moving averages, which might indicate a recent downward trend. The P/E ratio of 8.52 suggests that the stock is relatively inexpensive compared to its earnings, which could be seen as attractive to value investors.
#
# Is there any other information about MPC or its stock performance that you'd like to know?

# %%
query= "Give me the current price of MPC"
response = oai_agent.chat(query)
print(str(response))
# Out:
# > Running step 15a4b98c-0730-4e71-8339-693be097838f. Step input: Give me the current price of MPC
# Added user message to memory: Give me the current price of MPC
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "MPC"}
# === Function Output ===
# {'symbol': 'MPC', 'price': 162.5, 'volume': 1362630, 'avgVolume': 2703448, 'priceAvg50': 168.6334, 'priceAvg200': 174.57056, 'EPS': 19.07, 'PE': 8.52, 'earningsAnnouncement': '2024-11-05T13:30:00.000+0000'}
# > Running step 78e887eb-cb83-45e9-bd24-fe658d64731f. Step input: None
# === LLM Response ===
# The current price of MPC (Marathon Petroleum Corporation) is $162.50. Here are some additional details:
#
# - Trading Volume: 1,362,630
# - Average Volume: 2,703,448
# - 50-Day Average Price: $168.63
# - 200-Day Average Price: $174.57
# - Earnings Per Share (EPS): $19.07
# - Price/Earnings (P/E) Ratio: 8.52
# - Next Earnings Announcement: November 5, 2024, at 1:30 PM UTC.
# The current price of MPC (Marathon Petroleum Corporation) is $162.50. Here are some additional details:
#
# - Trading Volume: 1,362,630
# - Average Volume: 2,703,448
# - 50-Day Average Price: $168.63
# - 200-Day Average Price: $174.57
# - Earnings Per Share (EPS): $19.07
# - Price/Earnings (P/E) Ratio: 8.52
# - Next Earnings Announcement: November 5, 2024, at 1:30 PM UTC.

# %%
query= "Give me an analysis of ARM's financial conditions"
response = claude_agent.chat(query)
print(str(response))
# Out:
# > Running step 8fd98c51-5246-4ac3-b411-6573e4e93574. Step input: Give me an analysis of ARM's financial conditions
# Added user message to memory: Give me an analysis of ARM's financial conditions
# === LLM Response ===
# Certainly! I'll provide an analysis of ARM's (Arm Holdings plc) financial conditions using several tools to gather comprehensive information. Let's start by collecting data on the company's financials, stock price, and key metrics.
# === Calling Function ===
# Calling function: get_company_financials with args: {"symbol": "ARM"}
# === Function Output ===
# {'symbol': 'ARM', 'companyName': 'Arm Holdings plc American Depositary Shares', 'marketCap': 169587360000, 'industry': 'Semiconductors', 'sector': 'Technology', 'website': 'https://www.arm.com', 'beta': 0, 'price': 161.82}
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "ARM"}
# === Function Output ===
# {'symbol': 'ARM', 'price': 161.82, 'volume': 8557813, 'avgVolume': 7868101, 'priceAvg50': 132.5896, 'priceAvg200': 124.52117, 'EPS': 0.41, 'PE': 394.68, 'earningsAnnouncement': '2024-11-06T21:00:00.000+0000'}
# === Calling Function ===
# Calling function: get_key_metrics_ttm with args: {"symbol": "ARM"}
# === Function Output ===
# {'revenuePerShareTTM': 3.349616858237548, 'netIncomePerShareTTM': 0.4061302681992337, 'operatingCashFlowPerShareTTM': 0.8754789272030651, 'freeCashFlowPerShareTTM': 0.7270114942528736, 'cashPerShareTTM': 2.361111111111111, 'bookValuePerShareTTM': 5.424329501915709, 'tangibleBookValuePerShareTTM': 3.7155172413793105, 'marketCapTTM': 169587360000, 'enterpriseValueTTM': 168371360000, 'peRatioTTM': 398.4435849056604, 'priceToSalesRatioTTM': 48.49509865599085, 'priceToFCFRatioTTM': 223.43525691699605, 'priceToBookRatioTTM': 29.83225852021896, 'evToSalesTTM': 48.147372033171294, 'enterpriseValueOverEBITDATTM': 470.31106145251397, 'evToOperatingCashFlowTTM': 184.21374179431075, 'evToFreeCashFlowTTM': 221.83314888010543, 'earningsYieldTTM': 0.0025097655926290554, 'freeCashFlowYieldTTM': 0.004475569405644383, 'debtToEquityTTM': 0.04396962740596857, 'debtToAssetsTTM': 0.03159898477157361, 'netDebtToEBITDATTM': -3.3966480446927374, 'currentRatioTTM': 3.6056338028169015, 'interestCoverageTTM': 0, 'roicTTM': 0.0396740851639651}
# === Calling Function ===
# Calling function: get_income_statement with args: {"symbol": "ARM"}
# === Function Output ===
# ([{'date': '2024-03-31', 'symbol': 'ARM', 'reportedCurrency': 'USD', 'cik': '0001973239', 'fillingDate': '2024-05-29', 'acceptedDate': '2024-05-29 16:05:47', 'calendarYear': '2024', 'period': 'FY', 'revenue': 3233000000, 'costOfRevenue': 235000000, 'grossProfit': 2998000000, 'grossProfitRatio': 0.927312094, 'researchAndDevelopmentExpenses': 1987000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 912000000, 'otherExpenses': 11000000, 'operatingExpenses': 2899000000, 'costAndExpenses': 3134000000, 'interestIncome': 110000000, 'interestExpense': 0, 'depreciationAndAmortization': 162000000, 'ebitda': 261000000, 'ebitdaratio': 0.0807299722, 'operatingIncome': 99000000, 'operatingIncomeRatio': 0.0306217136, 'totalOtherIncomeExpensesNet': 113000000, 'incomeBeforeTax': 212000000, 'incomeBeforeTaxRatio': 0.0655737705, 'incomeTaxExpense': -94000000, 'netIncome': 306000000, 'netIncomeRatio': 0.0946489329, 'eps': 0.3, 'epsdiluted': 0.29, 'weightedAverageShsOut': 1027443121, 'weightedAverageShsOutDil': 1044497032, 'link': 'https://www.sec.gov/Archives/edgar/data/1973239/000197323924000012/0001973239-24-000012-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1973239/000197323924000012/arm-20240331.htm'}, {'date': '2023-03-31', 'symbol': 'ARM', 'reportedCurrency': 'USD', 'cik': '0001973239', 'fillingDate': '2023-03-31', 'acceptedDate': '2023-03-30 20:00:00', 'calendarYear': '2023', 'period': 'FY', 'revenue': 2679000000, 'costOfRevenue': 106000000, 'grossProfit': 2573000000, 'grossProfitRatio': 0.9604329974, 'researchAndDevelopmentExpenses': 1133000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 762000000, 'otherExpenses': 3000000, 'operatingExpenses': 1895000000, 'costAndExpenses': 2001000000, 'interestIncome': 42000000, 'interestExpense': 0, 'depreciationAndAmortization': 170000000, 'ebitda': 855000000, 'ebitdaratio': 0.3191489362, 'operatingIncome': 671000000, 'operatingIncomeRatio': 0.250466592, 'totalOtherIncomeExpensesNet': -49000000, 'incomeBeforeTax': 671000000, 'incomeBeforeTaxRatio': 0.250466592, 'incomeTaxExpense': 147000000, 'netIncome': 524000000, 'netIncomeRatio': 0.1955953714, 'eps': 0.51, 'epsdiluted': 0.51, 'weightedAverageShsOut': 1026054856, 'weightedAverageShsOutDil': 1026054856, 'link': None, 'finalLink': None}, {'date': '2022-03-31', 'symbol': 'ARM', 'reportedCurrency': 'USD', 'cik': '0001973239', 'fillingDate': '2022-03-31', 'acceptedDate': '2022-03-30 20:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 2703000000, 'costOfRevenue': 131000000, 'grossProfit': 2572000000, 'grossProfitRatio': 0.9515353311, 'researchAndDevelopmentExpenses': 995000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 897000000, 'otherExpenses': 10000000, 'operatingExpenses': 1892000000, 'costAndExpenses': 2023000000, 'interestIncome': 2000000, 'interestExpense': 0, 'depreciationAndAmortization': 185000000, 'ebitda': 912000000, 'ebitdaratio': 0.3374028857, 'operatingIncome': 633000000, 'operatingIncomeRatio': 0.2341842397, 'totalOtherIncomeExpensesNet': 104000000, 'incomeBeforeTax': 786000000, 'incomeBeforeTaxRatio': 0.2907880133, 'incomeTaxExpense': 110000000, 'netIncome': 549000000, 'netIncomeRatio': 0.2031076582, 'eps': 0.54, 'epsdiluted': 0.54, 'weightedAverageShsOut': 1026054856, 'weightedAverageShsOutDil': 1026054856, 'link': None, 'finalLink': None}, {'date': '2021-03-31', 'symbol': 'ARM', 'reportedCurrency': 'USD', 'cik': '0001973239', 'fillingDate': '2021-03-31', 'acceptedDate': '2021-03-30 20:00:00', 'calendarYear': '2021', 'period': 'FY', 'revenue': 2027000000, 'costOfRevenue': 145000000, 'grossProfit': 1882000000, 'grossProfitRatio': 0.9284657129, 'researchAndDevelopmentExpenses': 814000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeEx ...
# > Running step 9e7ee79a-b2f7-460e-9eaa-3bbefab16916. Step input: None
# === LLM Response ===
# Based on the information gathered, I'll provide an analysis of ARM's (Arm Holdings plc) financial conditions:
#
# 1. Company Overview:
#    - Industry: Semiconductors
#    - Sector: Technology
#    - Market Capitalization: $169.59 billion
#
# 2. Stock Performance:
#    - Current Price: $161.82
#    - 50-day Moving Average: $132.59
#    - 200-day Moving Average: $124.52
#    - The stock is trading above both its 50-day and 200-day moving averages, indicating a strong upward trend.
#
# 3. Valuation Metrics:
#    - Price-to-Earnings (P/E) Ratio: 394.68 (extremely high)
#    - Price-to-Sales Ratio: 48.50
#    - Price-to-Book Ratio: 29.83
#    - These valuation metrics suggest that ARM is trading at a premium compared to its earnings and book value, indicating high growth expectations from investors.
#
# 4. Financial Performance (FY 2024):
#    - Revenue: $3.233 billion
#    - Gross Profit: $2.998 billion
#    - Net Income: $306 million
#    - EBITDA: $261 million
#    - EPS (diluted): $0.29
#
# 5. Profitability:
#    - Gross Profit Margin: 92.73% (very high, indicating strong pricing power)
#    - Net Income Margin: 9.46%
#    - EBITDA Margin: 8.07%
#
# 6. Liquidity and Solvency:
#    - Current Ratio: 3.61 (strong short-term liquidity)
#    - Debt-to-Equity Ratio: 0.044 (very low leverage)
#    - Debt-to-Assets Ratio: 0.032 (minimal debt relative to assets)
#
# 7. Cash Flow:
#    - Operating Cash Flow per Share: $0.88
#    - Free Cash Flow per Share: $0.73
#    - The company is generating positive cash flows, which is a good sign for financial health.
#
# 8. Growth and Efficiency:
#    - Year-over-year revenue growth (2
# Based on the information gathered, I'll provide an analysis of ARM's (Arm Holdings plc) financial conditions:
#
# 1. Company Overview:
#    - Industry: Semiconductors
#    - Sector: Technology
#    - Market Capitalization: $169.59 billion
#
# 2. Stock Performance:
#    - Current Price: $161.82
#    - 50-day Moving Average: $132.59
#    - 200-day Moving Average: $124.52
#    - The stock is trading above both its 50-day and 200-day moving averages, indicating a strong upward trend.
#
# 3. Valuation Metrics:
#    - Price-to-Earnings (P/E) Ratio: 394.68 (extremely high)
#    - Price-to-Sales Ratio: 48.50
#    - Price-to-Book Ratio: 29.83
#    - These valuation metrics suggest that ARM is trading at a premium compared to its earnings and book value, indicating high growth expectations from investors.
#
# 4. Financial Performance (FY 2024):
#    - Revenue: $3.233 billion
#    - Gross Profit: $2.998 billion
#    - Net Income: $306 million
#    - EBITDA: $261 million
#    - EPS (diluted): $0.29
#
# 5. Profitability:
#    - Gross Profit Margin: 92.73% (very high, indicating strong pricing power)
#    - Net Income Margin: 9.46%
#    - EBITDA Margin: 8.07%
#
# 6. Liquidity and Solvency:
#    - Current Ratio: 3.61 (strong short-term liquidity)
#    - Debt-to-Equity Ratio: 0.044 (very low leverage)
#    - Debt-to-Assets Ratio: 0.032 (minimal debt relative to assets)
#
# 7. Cash Flow:
#    - Operating Cash Flow per Share: $0.88
#    - Free Cash Flow per Share: $0.73
#    - The company is generating positive cash flows, which is a good sign for financial health.
#
# 8. Growth and Efficiency:
#    - Year-over-year revenue growth (2

# %%
query= "Act like a value investor (such as Warren Buffett or Charlie Munger) and assess the financial health of MPLX"
response = claude_agent.chat(query)
print(str(response))
# Out:
# > Running step 44538dcb-d7f3-4e2d-92e0-3e941a7b6768. Step input: Act like a value investor (such as Warren Buffett or Charlie Munger) and assess the financial health of MPLX
# Added user message to memory: Act like a value investor (such as Warren Buffett or Charlie Munger) and assess the financial health of MPLX
# === LLM Response ===
# Certainly! I'll analyze MPLX from a value investor's perspective, focusing on the company's financial health, stability, and long-term prospects. Let's start by gathering the necessary financial information.
# === Calling Function ===
# Calling function: get_company_financials with args: {"symbol": "MPLX"}
# === Function Output ===
# {'symbol': 'MPLX', 'companyName': 'MPLX LP', 'marketCap': 44997372200, 'industry': 'Oil & Gas Midstream', 'sector': 'Energy', 'website': 'https://www.mplx.com', 'beta': 1.341, 'price': 44.09}
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "MPLX"}
# === Function Output ===
# {'symbol': 'MPLX', 'price': 44.09, 'volume': 1108825, 'avgVolume': 1460317, 'priceAvg50': 43.0798, 'priceAvg200': 41.0144, 'EPS': 4.12, 'PE': 10.7, 'earningsAnnouncement': '2024-11-05T00:00:00.000+0000'}
# === Calling Function ===
# Calling function: get_key_metrics_ttm with args: {"symbol": "MPLX"}
# === Function Output ===
# {'revenuePerShareTTM': 10.84396467124632, 'netIncomePerShareTTM': 4.1540726202158975, 'operatingCashFlowPerShareTTM': 5.4877330716388615, 'freeCashFlowPerShareTTM': 4.532875368007851, 'cashPerShareTTM': 2.4543670264965654, 'bookValuePerShareTTM': 13.621197252208047, 'tangibleBookValuePerShareTTM': 5.544651619234544, 'marketCapTTM': 44997372200, 'enterpriseValueTTM': 65069372200, 'peRatioTTM': 10.613680604772032, 'priceToSalesRatioTTM': 4.072160380090498, 'priceToFCFRatioTTM': 9.741799567005845, 'priceToBookRatioTTM': 3.2906840987328794, 'evToSalesTTM': 5.888630968325792, 'enterpriseValueOverEBITDATTM': 10.917679899328858, 'evToOperatingCashFlowTTM': 11.636153826895566, 'evToFreeCashFlowTTM': 14.087328902359818, 'earningsYieldTTM': 0.09421802268577675, 'freeCashFlowYieldTTM': 0.10265043877384467, 'debtToEquityTTM': 1.6203764740350106, 'debtToAssetsTTM': 0.5760897869902609, 'netDebtToEBITDATTM': 3.367785234899329, 'currentRatioTTM': 0.9929010884997633, 'interestCoverageTTM': 5.167579408543264, 'roicTTM': 0.13147612050967622}
# === Calling Function ===
# Calling function: get_income_statement with args: {"symbol": "MPLX"}
# === Function Output ===
# ([{'date': '2023-12-31', 'symbol': 'MPLX', 'reportedCurrency': 'USD', 'cik': '0001552000', 'fillingDate': '2024-02-28', 'acceptedDate': '2024-02-28 14:35:11', 'calendarYear': '2023', 'period': 'FY', 'revenue': 10692000000, 'costOfRevenue': 5860000000, 'grossProfit': 4832000000, 'grossProfitRatio': 0.4519266741, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 379000000, 'sellingAndMarketingExpenses': -9000000, 'sellingGeneralAndAdministrativeExpenses': 370000000, 'otherExpenses': -131000000, 'operatingExpenses': 501000000, 'costAndExpenses': 6361000000, 'interestIncome': 0, 'interestExpense': 938000000, 'depreciationAndAmortization': 1213000000, 'ebitda': 5544000000, 'ebitdaratio': 0.5185185185, 'operatingIncome': 4331000000, 'operatingIncomeRatio': 0.4050692106, 'totalOtherIncomeExpensesNet': -354000000, 'incomeBeforeTax': 3977000000, 'incomeBeforeTaxRatio': 0.3719603442, 'incomeTaxExpense': 11000000, 'netIncome': 3928000000, 'netIncomeRatio': 0.3673774785, 'eps': 3.83, 'epsdiluted': 3.82, 'weightedAverageShsOut': 1001000000, 'weightedAverageShsOutDil': 1002000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200024000007/0001552000-24-000007-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200024000007/mplx-20231231.htm'}, {'date': '2022-12-31', 'symbol': 'MPLX', 'reportedCurrency': 'USD', 'cik': '0001552000', 'fillingDate': '2023-02-23', 'acceptedDate': '2023-02-23 13:35:25', 'calendarYear': '2022', 'period': 'FY', 'revenue': 10541000000, 'costOfRevenue': 6252000000, 'grossProfit': 4289000000, 'grossProfitRatio': 0.4068873921, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 335000000, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 335000000, 'otherExpenses': -481000000, 'operatingExpenses': -146000000, 'costAndExpenses': 6106000000, 'interestIncome': 848000000, 'interestExpense': 925000000, 'depreciationAndAmortization': 1230000000, 'ebitda': 4911000000, 'ebitdaratio': 0.4658950764, 'operatingIncome': 3681000000, 'operatingIncomeRatio': 0.349207855, 'totalOtherIncomeExpensesNet': 305000000, 'incomeBeforeTax': 3986000000, 'incomeBeforeTaxRatio': 0.3781424912, 'incomeTaxExpense': 8000000, 'netIncome': 3944000000, 'netIncomeRatio': 0.3741580495, 'eps': 3.75, 'epsdiluted': 3.75, 'weightedAverageShsOut': 1010000000, 'weightedAverageShsOutDil': 1010000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200023000008/0001552000-23-000008-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200023000008/mplx-20221231.htm'}, {'date': '2021-12-31', 'symbol': 'MPLX', 'reportedCurrency': 'USD', 'cik': '0001552000', 'fillingDate': '2022-02-24', 'acceptedDate': '2022-02-24 13:10:28', 'calendarYear': '2021', 'period': 'FY', 'revenue': 9575000000, 'costOfRevenue': 5520000000, 'grossProfit': 4055000000, 'grossProfitRatio': 0.4234986945, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 353000000, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 353000000, 'otherExpenses': -11000000, 'operatingExpenses': 342000000, 'costAndExpenses': 5862000000, 'interestIncome': 793000000, 'interestExpense': 879000000, 'depreciationAndAmortization': 1287000000, 'ebitda': 4034000000, 'ebitdaratio': 0.421305483, 'operatingIncome': 2747000000, 'operatingIncomeRatio': 0.2868929504, 'totalOtherIncomeExpensesNet': 366000000, 'incomeBeforeTax': 3113000000, 'incomeBeforeTaxRatio': 0.3251174935, 'incomeTaxExpense': 1000000, 'netIncome': 3077000000, 'netIncomeRatio': 0.3213577023, 'eps': 2.86, 'epsdiluted': 2.86, 'weightedAverageShsOut': 1027000000, 'weightedAverageShsOutDil': 1027000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200022000007/0001552000-22-000007-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1552000/000155200022000007/mplx-20211231.htm'}, {'date': '2020-12-31', 'symbol': 'MPLX', 'reportedCurre ...
# > Running step ac96babe-71ca-423c-8aa5-c25a897ee215. Step input: None
# === LLM Response ===
# Now, let's analyze MPLX from a value investor's perspective:
#
# 1. Business Model and Industry:
#    MPLX LP operates in the Oil & Gas Midstream industry, which is part of the Energy sector. Midstream companies typically have more stable cash flows compared to upstream (exploration and production) or downstream (refining and marketing) companies. This stability is attractive from a value investing standpoint.
#
# 2. Financial Strength:
#    - Debt-to-Equity Ratio: 1.62
#    - Current Ratio: 0.99
#    - Interest Coverage Ratio: 5.17
#
#    The debt-to-equity ratio is somewhat high, but not uncommon for capital-intensive industries like midstream energy. The current ratio is close to 1, indicating adequate liquidity. The interest coverage ratio of 5.17 shows that the company can comfortably meet its interest obligations, which is positive.
#
# 3. Profitability:
#    - Net Income (2023): $3.928 billion
#    - Net Profit Margin: 36.74%
#    - Return on Invested Capital (ROIC): 13.15%
#
#    MPLX demonstrates strong profitability with a high net profit margin and a solid ROIC. This indicates efficient use of capital and effective cost management.
#
# 4. Earnings Stability:
#    Looking at the historical data, MPLX has shown consistent growth in revenue and net income over the years, with the exception of 2020 (likely due to the pandemic). This stability in earnings is a positive sign for value investors.
#
# 5. Dividend:
#    While not explicitly stated in the data provided, midstream companies often offer attractive dividends. The company's strong cash flow and profitability suggest it likely has a sustainable dividend policy.
#
# 6. Valuation:
#    - P/E Ratio: 10.7
#    - Price-to-Book Ratio: 3.29
#    - EV/EBITDA: 10.92
#
#    The P/E ratio of 10.7 is relatively low, especially considering the company's profitability and growth. This could indicate that the stock is undervalued. The EV/EBITDA ratio of 10.92 is reasonable for the industry.
#
# 7
# Now, let's analyze MPLX from a value investor's perspective:
#
# 1. Business Model and Industry:
#    MPLX LP operates in the Oil & Gas Midstream industry, which is part of the Energy sector. Midstream companies typically have more stable cash flows compared to upstream (exploration and production) or downstream (refining and marketing) companies. This stability is attractive from a value investing standpoint.
#
# 2. Financial Strength:
#    - Debt-to-Equity Ratio: 1.62
#    - Current Ratio: 0.99
#    - Interest Coverage Ratio: 5.17
#
#    The debt-to-equity ratio is somewhat high, but not uncommon for capital-intensive industries like midstream energy. The current ratio is close to 1, indicating adequate liquidity. The interest coverage ratio of 5.17 shows that the company can comfortably meet its interest obligations, which is positive.
#
# 3. Profitability:
#    - Net Income (2023): $3.928 billion
#    - Net Profit Margin: 36.74%
#    - Return on Invested Capital (ROIC): 13.15%
#
#    MPLX demonstrates strong profitability with a high net profit margin and a solid ROIC. This indicates efficient use of capital and effective cost management.
#
# 4. Earnings Stability:
#    Looking at the historical data, MPLX has shown consistent growth in revenue and net income over the years, with the exception of 2020 (likely due to the pandemic). This stability in earnings is a positive sign for value investors.
#
# 5. Dividend:
#    While not explicitly stated in the data provided, midstream companies often offer attractive dividends. The company's strong cash flow and profitability suggest it likely has a sustainable dividend policy.
#
# 6. Valuation:
#    - P/E Ratio: 10.7
#    - Price-to-Book Ratio: 3.29
#    - EV/EBITDA: 10.92
#
#    The P/E ratio of 10.7 is relatively low, especially considering the company's profitability and growth. This could indicate that the stock is undervalued. The EV/EBITDA ratio of 10.92 is reasonable for the industry.
#
# 7

# %%
query= "Give me an analysis of BMW's parent company stock profile"
response = claude_agent.chat(query)
print(str(response))
# Out:
# > Running step e7f49377-178c-42d5-9523-3778fc30180e. Step input: Give me an analysis of BMW's parent company stock profile
# Added user message to memory: Give me an analysis of BMW's parent company stock profile
# === LLM Response ===
# Certainly! I'll analyze the stock profile of BMW's parent company, which is Bayerische Motoren Werke AG, commonly known as BMW. The stock is traded under the ticker symbol "BMW" on the Frankfurt Stock Exchange. Let's gather the relevant information and provide an analysis.
# === Calling Function ===
# Calling function: get_company_financials with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'symbol': 'BMW.DE', 'companyName': 'Bayerische Motoren Werke Aktiengesellschaft', 'marketCap': 47790822752, 'industry': 'Auto - Manufacturers', 'sector': 'Consumer Cyclical', 'website': 'https://www.bmwgroup.com', 'beta': 1.076, 'price': 76.24}
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'symbol': 'BMW.DE', 'price': 76.24, 'volume': 652628, 'avgVolume': 1120167, 'priceAvg50': 78.7092, 'priceAvg200': 93.49125, 'EPS': 16.54, 'PE': 4.61, 'earningsAnnouncement': '2024-11-06T06:30:00.000+0000'}
# === Calling Function ===
# Calling function: get_key_metrics_ttm with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'revenuePerShareTTM': 242.5747713638792, 'netIncomePerShareTTM': 16.385660980542838, 'operatingCashFlowPerShareTTM': 18.48767098119897, 'freeCashFlowPerShareTTM': -0.18312373051136804, 'cashPerShareTTM': 33.17356810417475, 'bookValuePerShareTTM': 146.3017742377745, 'tangibleBookValuePerShareTTM': 115.70445964147764, 'marketCapTTM': 47790822752, 'enterpriseValueTTM': 132194822752, 'peRatioTTM': 4.652848615050148, 'priceToSalesRatioTTM': 0.30835971940329326, 'priceToFCFRatioTTM': -408.46857052991453, 'priceToBookRatioTTM': 0.5357825677936533, 'evToSalesTTM': 0.8529578714706034, 'enterpriseValueOverEBITDATTM': 5.2131407347582615, 'evToOperatingCashFlowTTM': 11.191569823230614, 'evToFreeCashFlowTTM': -1129.8702799316238, 'earningsYieldTTM': 0.2149221010039722, 'freeCashFlowYieldTTM': -0.0024481687751463465, 'debtToEquityTTM': 1.1247868888522246, 'debtToAssetsTTM': 0.3946799641831599, 'netDebtToEBITDATTM': 3.3284959381654704, 'currentRatioTTM': 1.1033758827029516, 'interestCoverageTTM': 24.875375375375377, 'roicTTM': 0.061009763736025756}
# === Calling Function ===
# Calling function: get_income_statement with args: {"symbol": "BMW.DE"}
# === Function Output ===
# ([{'date': '2023-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2023-12-31', 'acceptedDate': '2023-12-29 19:00:00', 'calendarYear': '2023', 'period': 'FY', 'revenue': 155498000000, 'costOfRevenue': 118271000000, 'grossProfit': 37227000000, 'grossProfitRatio': 0.2394050084, 'researchAndDevelopmentExpenses': 7538000000, 'generalAndAdministrativeExpenses': 4934000000, 'sellingAndMarketingExpenses': 6091000000, 'sellingGeneralAndAdministrativeExpenses': 11038000000, 'otherExpenses': -159000000, 'operatingExpenses': 18735000000, 'costAndExpenses': 137006000000, 'interestIncome': 701000000, 'interestExpense': 656000000, 'depreciationAndAmortization': 8974000000, 'ebitda': 27466000000, 'ebitdaratio': 0.1766324969, 'operatingIncome': 18492000000, 'operatingIncomeRatio': 0.1189211437, 'totalOtherIncomeExpensesNet': -1237000000, 'incomeBeforeTax': 17255000000, 'incomeBeforeTaxRatio': 0.1109660574, 'incomeTaxExpense': 4931000000, 'netIncome': 11290000000, 'netIncomeRatio': 0.0726054354, 'eps': 17.67, 'epsdiluted': 17.67, 'weightedAverageShsOut': 638913477, 'weightedAverageShsOutDil': 638913477, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0'}, {'date': '2022-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2022-12-31', 'acceptedDate': '2022-12-30 19:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 142610000000, 'costOfRevenue': 118042000000, 'grossProfit': 24568000000, 'grossProfitRatio': 0.1722740341, 'researchAndDevelopmentExpenses': 6624000000, 'generalAndAdministrativeExpenses': 4425000000, 'sellingAndMarketingExpenses': 6191000000, 'sellingGeneralAndAdministrativeExpenses': 10616000000, 'otherExpenses': -257000000, 'operatingExpenses': 10359000000, 'costAndExpenses': 128401000000, 'interestIncome': 903000000, 'interestExpense': 230000000, 'depreciationAndAmortization': 8566000000, 'ebitda': 32529000000, 'ebitdaratio': 0.2280976089, 'operatingIncome': 23963000000, 'operatingIncomeRatio': 0.1680316948, 'totalOtherIncomeExpensesNet': -454000000, 'incomeBeforeTax': 23509000000, 'incomeBeforeTaxRatio': 0.1648481874, 'incomeTaxExpense': 4927000000, 'netIncome': 17941000000, 'netIncomeRatio': 0.125804642, 'eps': 27.3, 'epsdiluted': 27.3, 'weightedAverageShsOut': 657098549, 'weightedAverageShsOutDil': 657098549, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0'}, {'date': '2021-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2021-12-31', 'acceptedDate': '2021-12-30 19:00:00', 'calendarYear': '2021', 'period': 'FY', 'revenue': 111239000000, 'costOfRevenue': 89253000000, 'grossProfit': 21986000000, 'grossProfitRatio': 0.1976465089, 'researchAndDevelopmentExpenses': 6299000000, 'generalAndAdministrativeExpenses': 3909000000, 'sellingAndMarketingExpenses': 5324000000, 'sellingGeneralAndAdministrativeExpenses': 9233000000, 'otherExpenses': -701000000, 'operatingExpenses': 8532000000, 'costAndExpenses': 97785000000, 'interestIncome': 206000000, 'interestExpense': 236000000, 'depreciationAndAmortization': 6495000000, 'ebitda': 22873000000, 'ebitdaratio': 0.205620331, 'operatingIncome': 16378000000, 'operatingIncomeRatio': 0.1472325354, 'totalOtherIncomeExpensesNet': -318000000, 'incomeBeforeTax': 16060000000, 'incomeBeforeTaxRatio': 0.1443738257, 'incomeTaxExpense': 3597000000, 'netIncome': 12382000000, 'netIncomeRatio': 0.1113098823, 'eps': 18.76, 'epsdiluted': 18.76, 'weightedAverageShsOut': 659880348, 'weightedAverageShsOutDil': 659880348, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesan ...
# > Running step ac5477f3-1649-4ec4-8eee-f1f506071564. Step input: None
# === LLM Response ===
# Based on the information provided, I'll analyze BMW's (Bayerische Motoren Werke AG) stock profile:
#
# 1. Company Overview:
#    - Symbol: BMW.DE (Frankfurt Stock Exchange)
#    - Industry: Auto Manufacturers
#    - Sector: Consumer Cyclical
#    - Market Cap: €47.79 billion
#
# 2. Stock Performance:
#    - Current Price: €76.24
#    - 50-day Moving Average: €78.71
#    - 200-day Moving Average: €93.49
#    - The stock is currently trading below both its 50-day and 200-day moving averages, indicating a potential downward trend.
#
# 3. Valuation Metrics:
#    - Price-to-Earnings (P/E) Ratio: 4.61
#    - Price-to-Sales Ratio: 0.31
#    - Price-to-Book Ratio: 0.54
#    - Enterprise Value to EBITDA: 5.21
#    These valuation metrics suggest that BMW's stock is trading at relatively low multiples, which could indicate that it's undervalued compared to its peers or the broader market.
#
# 4. Financial Performance (FY 2023):
#    - Revenue: €155.50 billion
#    - Gross Profit: €37.23 billion
#    - Net Income: €11.29 billion
#    - EBITDA: €27.47 billion
#    - EPS: €17.67
#
# 5. Profitability:
#    - Gross Profit Margin: 23.94%
#    - Net Profit Margin: 7.26%
#    - Return on Invested Capital (ROIC): 6.10%
#    BMW's profitability metrics are solid for the automotive industry, which typically operates on thin margins.
#
# 6. Debt and Liquidity:
#    - Debt-to-Equity Ratio: 1.12
#    - Current Ratio: 1.10
#    - Interest Coverage Ratio: 24.88
#    The company has a moderate level of debt, but its strong interest coverage ratio indicates that it can comfortably meet its debt obligations.
#
# 7. Cash Flow:
#    - Operating Cash Flow per Share: €18.49
# Based on the information provided, I'll analyze BMW's (Bayerische Motoren Werke AG) stock profile:
#
# 1. Company Overview:
#    - Symbol: BMW.DE (Frankfurt Stock Exchange)
#    - Industry: Auto Manufacturers
#    - Sector: Consumer Cyclical
#    - Market Cap: €47.79 billion
#
# 2. Stock Performance:
#    - Current Price: €76.24
#    - 50-day Moving Average: €78.71
#    - 200-day Moving Average: €93.49
#    - The stock is currently trading below both its 50-day and 200-day moving averages, indicating a potential downward trend.
#
# 3. Valuation Metrics:
#    - Price-to-Earnings (P/E) Ratio: 4.61
#    - Price-to-Sales Ratio: 0.31
#    - Price-to-Book Ratio: 0.54
#    - Enterprise Value to EBITDA: 5.21
#    These valuation metrics suggest that BMW's stock is trading at relatively low multiples, which could indicate that it's undervalued compared to its peers or the broader market.
#
# 4. Financial Performance (FY 2023):
#    - Revenue: €155.50 billion
#    - Gross Profit: €37.23 billion
#    - Net Income: €11.29 billion
#    - EBITDA: €27.47 billion
#    - EPS: €17.67
#
# 5. Profitability:
#    - Gross Profit Margin: 23.94%
#    - Net Profit Margin: 7.26%
#    - Return on Invested Capital (ROIC): 6.10%
#    BMW's profitability metrics are solid for the automotive industry, which typically operates on thin margins.
#
# 6. Debt and Liquidity:
#    - Debt-to-Equity Ratio: 1.12
#    - Current Ratio: 1.10
#    - Interest Coverage Ratio: 24.88
#    The company has a moderate level of debt, but its strong interest coverage ratio indicates that it can comfortably meet its debt obligations.
#
# 7. Cash Flow:
#    - Operating Cash Flow per Share: €18.49

# %%
query= "Give me an analysis of BMW's parent company stock profile"
response = oai_agent.chat(query)
print(str(response))
# Out:
# > Running step 2e21a56a-959c-49c4-b98e-be85455dadb5. Step input: Give me an analysis of BMW's parent company stock profile
# Added user message to memory: Give me an analysis of BMW's parent company stock profile
# === Calling Function ===
# Calling function: get_stock_price with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'symbol': 'BMW.DE', 'price': 76.24, 'volume': 652628, 'avgVolume': 1120167, 'priceAvg50': 78.7092, 'priceAvg200': 93.49125, 'EPS': 16.54, 'PE': 4.61, 'earningsAnnouncement': '2024-11-06T06:30:00.000+0000'}
# === Calling Function ===
# Calling function: get_company_financials with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'symbol': 'BMW.DE', 'companyName': 'Bayerische Motoren Werke Aktiengesellschaft', 'marketCap': 47790822752, 'industry': 'Auto - Manufacturers', 'sector': 'Consumer Cyclical', 'website': 'https://www.bmwgroup.com', 'beta': 1.076, 'price': 76.24}
# === Calling Function ===
# Calling function: get_key_metrics_ttm with args: {"symbol": "BMW.DE"}
# === Function Output ===
# {'revenuePerShareTTM': 242.5747713638792, 'netIncomePerShareTTM': 16.385660980542838, 'operatingCashFlowPerShareTTM': 18.48767098119897, 'freeCashFlowPerShareTTM': -0.18312373051136804, 'cashPerShareTTM': 33.17356810417475, 'bookValuePerShareTTM': 146.3017742377745, 'tangibleBookValuePerShareTTM': 115.70445964147764, 'marketCapTTM': 47790822752, 'enterpriseValueTTM': 132194822752, 'peRatioTTM': 4.652848615050148, 'priceToSalesRatioTTM': 0.30835971940329326, 'priceToFCFRatioTTM': -408.46857052991453, 'priceToBookRatioTTM': 0.5357825677936533, 'evToSalesTTM': 0.8529578714706034, 'enterpriseValueOverEBITDATTM': 5.2131407347582615, 'evToOperatingCashFlowTTM': 11.191569823230614, 'evToFreeCashFlowTTM': -1129.8702799316238, 'earningsYieldTTM': 0.2149221010039722, 'freeCashFlowYieldTTM': -0.0024481687751463465, 'debtToEquityTTM': 1.1247868888522246, 'debtToAssetsTTM': 0.3946799641831599, 'netDebtToEBITDATTM': 3.3284959381654704, 'currentRatioTTM': 1.1033758827029516, 'interestCoverageTTM': 24.875375375375377, 'roicTTM': 0.061009763736025756}
# === Calling Function ===
# Calling function: get_income_statement with args: {"symbol": "BMW.DE"}
# === Function Output ===
# ([{'date': '2023-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2023-12-31', 'acceptedDate': '2023-12-29 19:00:00', 'calendarYear': '2023', 'period': 'FY', 'revenue': 155498000000, 'costOfRevenue': 118271000000, 'grossProfit': 37227000000, 'grossProfitRatio': 0.2394050084, 'researchAndDevelopmentExpenses': 7538000000, 'generalAndAdministrativeExpenses': 4934000000, 'sellingAndMarketingExpenses': 6091000000, 'sellingGeneralAndAdministrativeExpenses': 11038000000, 'otherExpenses': -159000000, 'operatingExpenses': 18735000000, 'costAndExpenses': 137006000000, 'interestIncome': 701000000, 'interestExpense': 656000000, 'depreciationAndAmortization': 8974000000, 'ebitda': 27466000000, 'ebitdaratio': 0.1766324969, 'operatingIncome': 18492000000, 'operatingIncomeRatio': 0.1189211437, 'totalOtherIncomeExpensesNet': -1237000000, 'incomeBeforeTax': 17255000000, 'incomeBeforeTaxRatio': 0.1109660574, 'incomeTaxExpense': 4931000000, 'netIncome': 11290000000, 'netIncomeRatio': 0.0726054354, 'eps': 17.67, 'epsdiluted': 17.67, 'weightedAverageShsOut': 638913477, 'weightedAverageShsOutDil': 638913477, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0'}, {'date': '2022-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2022-12-31', 'acceptedDate': '2022-12-30 19:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 142610000000, 'costOfRevenue': 118042000000, 'grossProfit': 24568000000, 'grossProfitRatio': 0.1722740341, 'researchAndDevelopmentExpenses': 6624000000, 'generalAndAdministrativeExpenses': 4425000000, 'sellingAndMarketingExpenses': 6191000000, 'sellingGeneralAndAdministrativeExpenses': 10616000000, 'otherExpenses': -257000000, 'operatingExpenses': 10359000000, 'costAndExpenses': 128401000000, 'interestIncome': 903000000, 'interestExpense': 230000000, 'depreciationAndAmortization': 8566000000, 'ebitda': 32529000000, 'ebitdaratio': 0.2280976089, 'operatingIncome': 23963000000, 'operatingIncomeRatio': 0.1680316948, 'totalOtherIncomeExpensesNet': -454000000, 'incomeBeforeTax': 23509000000, 'incomeBeforeTaxRatio': 0.1648481874, 'incomeTaxExpense': 4927000000, 'netIncome': 17941000000, 'netIncomeRatio': 0.125804642, 'eps': 27.3, 'epsdiluted': 27.3, 'weightedAverageShsOut': 657098549, 'weightedAverageShsOutDil': 657098549, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0'}, {'date': '2021-12-31', 'symbol': 'BMW.DE', 'reportedCurrency': 'EUR', 'cik': '0000000000', 'fillingDate': '2021-12-31', 'acceptedDate': '2021-12-30 19:00:00', 'calendarYear': '2021', 'period': 'FY', 'revenue': 111239000000, 'costOfRevenue': 89253000000, 'grossProfit': 21986000000, 'grossProfitRatio': 0.1976465089, 'researchAndDevelopmentExpenses': 6299000000, 'generalAndAdministrativeExpenses': 3909000000, 'sellingAndMarketingExpenses': 5324000000, 'sellingGeneralAndAdministrativeExpenses': 9233000000, 'otherExpenses': -701000000, 'operatingExpenses': 8532000000, 'costAndExpenses': 97785000000, 'interestIncome': 206000000, 'interestExpense': 236000000, 'depreciationAndAmortization': 6495000000, 'ebitda': 22873000000, 'ebitdaratio': 0.205620331, 'operatingIncome': 16378000000, 'operatingIncomeRatio': 0.1472325354, 'totalOtherIncomeExpensesNet': -318000000, 'incomeBeforeTax': 16060000000, 'incomeBeforeTaxRatio': 0.1443738257, 'incomeTaxExpense': 3597000000, 'netIncome': 12382000000, 'netIncomeRatio': 0.1113098823, 'eps': 18.76, 'epsdiluted': 18.76, 'weightedAverageShsOut': 659880348, 'weightedAverageShsOutDil': 659880348, 'link': 'https://www.bundesanzeiger.de/pub/de/suche;wwwsid=627BFD7A56A5CB624C47FDDEAB2FC509.web07-pub?0', 'finalLink': 'https://www.bundesan ...
# > Running step 9f98bbe4-0163-4dcf-9c5f-4ee294f3161f. Step input: None
# === LLM Response ===
# Here's an analysis of BMW's parent company, Bayerische Motoren Werke Aktiengesellschaft (BMW.DE):
#
# ### Current Stock Profile
# - **Current Price**: €76.24
# - **Trading Volume**: 652,628
# - **Average Volume**: 1,120,167
# - **50-Day Average Price**: €78.71
# - **200-Day Average Price**: €93.49
# - **Earnings Per Share (EPS)**: €16.54
# - **Price/Earnings (P/E) Ratio**: 4.61
# - **Next Earnings Announcement**: November 6, 2024
#
# ### Company Overview
# - **Company Name**: Bayerische Motoren Werke Aktiengesellschaft
# - **Market Capitalization**: €47.79 billion
# - **Industry**: Auto - Manufacturers
# - **Sector**: Consumer Cyclical
# - **Website**: [BMW Group](https://www.bmwgroup.com)
# - **Beta**: 1.076 (indicating volatility compared to the market)
#
# ### Key Financial Metrics (TTM)
# - **Revenue Per Share**: €242.57
# - **Net Income Per Share**: €16.39
# - **Operating Cash Flow Per Share**: €18.49
# - **Free Cash Flow Per Share**: -€0.18
# - **Cash Per Share**: €33.17
# - **Book Value Per Share**: €146.30
# - **Tangible Book Value Per Share**: €115.70
# - **Market Cap (TTM)**: €47.79 billion
# - **Enterprise Value (TTM)**: €132.19 billion
# - **P/E Ratio (TTM)**: 4.65
# - **Price to Sales Ratio (TTM)**: 0.31
# - **Price to Book Ratio (TTM)**: 0.54
# - **Debt to Equity Ratio (TTM)**: 1.12
# - **Current Ratio (TTM)**: 1.10
# - **Interest Coverage Ratio (TTM)**: 24.88
#
# ### Recent Income Statement Highlights (FY 2023)
# - **Revenue**: €155.50 billion
# - **Cost of Revenue**: €118.27 billion
# - **Gross Profit**: €37.23 billion
# - **Operating Income**: €18.49 billion
# - **Net Income**: €11.29 billion
# - **EPS**: €17.67
#
# ### Summary
# BMW is currently trading at €76.24 with a low P/E ratio of 4.61, indicating that the stock may be undervalued compared to its earnings. The company has a strong market capitalization of €47.79 billion and has shown solid revenue growth, with a net income of €11.29 billion in the latest fiscal year. However, the negative free cash flow per share may raise concerns about liquidity. Overall, BMW appears to be a solid investment opportunity, especially for those looking for value in the automotive sector.
# Here's an analysis of BMW's parent company, Bayerische Motoren Werke Aktiengesellschaft (BMW.DE):
#
# ### Current Stock Profile
# - **Current Price**: €76.24
# - **Trading Volume**: 652,628
# - **Average Volume**: 1,120,167
# - **50-Day Average Price**: €78.71
# - **200-Day Average Price**: €93.49
# - **Earnings Per Share (EPS)**: €16.54
# - **Price/Earnings (P/E) Ratio**: 4.61
# - **Next Earnings Announcement**: November 6, 2024
#
# ### Company Overview
# - **Company Name**: Bayerische Motoren Werke Aktiengesellschaft
# - **Market Capitalization**: €47.79 billion
# - **Industry**: Auto - Manufacturers
# - **Sector**: Consumer Cyclical
# - **Website**: [BMW Group](https://www.bmwgroup.com)
# - **Beta**: 1.076 (indicating volatility compared to the market)
#
# ### Key Financial Metrics (TTM)
# - **Revenue Per Share**: €242.57
# - **Net Income Per Share**: €16.39
# - **Operating Cash Flow Per Share**: €18.49
# - **Free Cash Flow Per Share**: -€0.18
# - **Cash Per Share**: €33.17
# - **Book Value Per Share**: €146.30
# - **Tangible Book Value Per Share**: €115.70
# - **Market Cap (TTM)**: €47.79 billion
# - **Enterprise Value (TTM)**: €132.19 billion
# - **P/E Ratio (TTM)**: 4.65
# - **Price to Sales Ratio (TTM)**: 0.31
# - **Price to Book Ratio (TTM)**: 0.54
# - **Debt to Equity Ratio (TTM)**: 1.12
# - **Current Ratio (TTM)**: 1.10
# - **Interest Coverage Ratio (TTM)**: 24.88
#
# ### Recent Income Statement Highlights (FY 2023)
# - **Revenue**: €155.50 billion
# - **Cost of Revenue**: €118.27 billion
# - **Gross Profit**: €37.23 billion
# - **Operating Income**: €18.49 billion
# - **Net Income**: €11.29 billion
# - **EPS**: €17.67
#
# ### Summary
# BMW is currently trading at €76.24 with a low P/E ratio of 4.61, indicating that the stock may be undervalued compared to its earnings. The company has a strong market capitalization of €47.79 billion and has shown solid revenue growth, with a net income of €11.29 billion in the latest fiscal year. However, the negative free cash flow per share may raise concerns about liquidity. Overall, BMW appears to be a solid investment opportunity, especially for those looking for value in the automotive sector.

# %%
query= "Screen for 30 stocks above $1 billion in market cap that would fit the Magic Formula Investing framework"
response = claude_agent.chat(query)
print(str(response))
# Out:
# > Running step 07975ca6-974b-4793-80ef-f79f312297ee. Step input: Screen for 30 stocks above $1 billion in market cap that would fit the Magic Formula Investing framework
# Added user message to memory: Screen for 30 stocks above $1 billion in market cap that would fit the Magic Formula Investing framework
# === LLM Response ===
# To screen for 30 stocks that would fit the Magic Formula Investing framework, we need to focus on companies with high earnings yield and high return on capital. The Magic Formula, developed by Joel Greenblatt, typically looks for companies with:
#
# 1. Market capitalization above $1 billion
# 2. High earnings yield (EBIT / Enterprise Value)
# 3. High return on capital (EBIT / (Net Working Capital + Net Fixed Assets))
#
# Unfortunately, I don't have access to a comprehensive database of all stocks and their financial metrics to perform this screen in real-time. However, I can explain the process and provide some general guidance on how you could perform this screen:
#
# 1. Start with a universe of stocks with market capitalization above $1 billion.
#
# 2. Calculate the earnings yield for each company:
#    Earnings Yield = EBIT / Enterprise Value
#    Where:
#    - EBIT is Earnings Before Interest and Taxes
#    - Enterprise Value = Market Cap + Total Debt - Cash and Cash Equivalents
#
# 3. Calculate the return on capital for each company:
#    Return on Capital = EBIT / (Net Working Capital + Net Fixed Assets)
#    Where:
#    - Net Working Capital = Current Assets - Current Liabilities
#    - Net Fixed Assets = Property, Plant, and Equipment
#
# 4. Rank all companies based on their earnings yield (highest to lowest).
#
# 5. Rank all companies based on their return on capital (highest to lowest).
#
# 6. Combine the two rankings (add the earnings yield rank and the return on capital rank for each company).
#
# 7. Sort the companies based on their combined ranking (lowest combined rank is best).
#
# 8. Select the top 30 companies from this sorted list.
#
# To actually perform this screen, you would need access to a financial database or screening tool that provides the necessary financial data for a large number of companies. Some popular resources for this kind of screening include:
#
# 1. FinViz
# 2. Yahoo Finance
# 3. Morningstar
# 4. S&P Capital IQ
# 5. Bloomberg Terminal (professional service)
#
# Keep in mind that the Magic Formula is just a starting point for investment research. It's important to conduct further analysis on any companies that pass this initial screen, including:
#
# 1. Analyzing the company's business model and competitive position
# 2. Reviewing recent financial
# To screen for 30 stocks that would fit the Magic Formula Investing framework, we need to focus on companies with high earnings yield and high return on capital. The Magic Formula, developed by Joel Greenblatt, typically looks for companies with:
#
# 1. Market capitalization above $1 billion
# 2. High earnings yield (EBIT / Enterprise Value)
# 3. High return on capital (EBIT / (Net Working Capital + Net Fixed Assets))
#
# Unfortunately, I don't have access to a comprehensive database of all stocks and their financial metrics to perform this screen in real-time. However, I can explain the process and provide some general guidance on how you could perform this screen:
#
# 1. Start with a universe of stocks with market capitalization above $1 billion.
#
# 2. Calculate the earnings yield for each company:
#    Earnings Yield = EBIT / Enterprise Value
#    Where:
#    - EBIT is Earnings Before Interest and Taxes
#    - Enterprise Value = Market Cap + Total Debt - Cash and Cash Equivalents
#
# 3. Calculate the return on capital for each company:
#    Return on Capital = EBIT / (Net Working Capital + Net Fixed Assets)
#    Where:
#    - Net Working Capital = Current Assets - Current Liabilities
#    - Net Fixed Assets = Property, Plant, and Equipment
#
# 4. Rank all companies based on their earnings yield (highest to lowest).
#
# 5. Rank all companies based on their return on capital (highest to lowest).
#
# 6. Combine the two rankings (add the earnings yield rank and the return on capital rank for each company).
#
# 7. Sort the companies based on their combined ranking (lowest combined rank is best).
#
# 8. Select the top 30 companies from this sorted list.
#
# To actually perform this screen, you would need access to a financial database or screening tool that provides the necessary financial data for a large number of companies. Some popular resources for this kind of screening include:
#
# 1. FinViz
# 2. Yahoo Finance
# 3. Morningstar
# 4. S&P Capital IQ
# 5. Bloomberg Terminal (professional service)
#
# Keep in mind that the Magic Formula is just a starting point for investment research. It's important to conduct further analysis on any companies that pass this initial screen, including:
#
# 1. Analyzing the company's business model and competitive position
# 2. Reviewing recent financial

# %% [markdown]
# ## 5. Testing and Chaining Different Tools

# %% [markdown]
# ### 5.1. Politician Tracker (Senate and House Trading Activity)

# %%
senate_trades_tool = FunctionTool.from_defaults(fn=get_senate_trades)
house_trades_tool = FunctionTool.from_defaults(fn=get_house_trades)

# %%
from llama_index.core.agent import FunctionCallingAgent

claude_politician_trades_tracker = FunctionCallingAgent.from_tools(
    [stock_price_tool, tool_income_statement, senate_trades_tool, house_trades_tool],
    llm=anthropic_llm,
    verbose=True,
    allow_parallel_tool_calls=True,
)

# %%
query= "Who are the most high profile politicians trading NVDA?"
response = claude_politician_trades_tracker.chat(query)
print(str(response))
# Out:
# > Running step ae5bd8d7-1715-450d-bdd6-b663f485ca00. Step input: Who are the most high profile politicians trading NVDA?
# Added user message to memory: Who are the most high profile politicians trading NVDA?
# === LLM Response ===
# To answer your question about high-profile politicians trading NVDA (NVIDIA Corporation), we'll need to check both Senate and House trading records for this stock. Let's use the available tools to gather this information.
# === Calling Function ===
# Calling function: get_senate_trades with args: {"symbol": "NVDA"}
# === Function Output ===
# {'symbol': 'NVDA', 'assetName': 'NVIDIA Corporation - Common Stock', 'assetType': 'Stock', 'firstName': 'Tommy', 'lastName': 'Tuberville', 'office': 'Tommy Tuberville', 'link': 'https://efdsearch.senate.gov/search/view/ptr/dda61a64-82ed-4cc8-87e7-ef1d256c6565/', 'date': '2024-05-14', 'transactionDate': '2024-04-30', 'owner': 'Joint', 'type': 'Sale (Full)', 'amount': '$15,001 - $50,000', 'comment': '--'}
# === Calling Function ===
# Calling function: get_house_trades with args: {"symbol": "NVDA"}
# === Function Output ===
# {'ticker': 'NVDA', 'assetName': 'NVIDIA Corporation - Common Stock', 'representative': 'Pete Sessions', 'district': 'TX17', 'link': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2024/20025867.pdf', 'date': '2024-09-16', 'transactionDate': '2024-09-16', 'owner': 'Spouse', 'type': 'Purchase', 'amount': '$1,001 - $15,000', 'capitalGainsOver200USD': 'False'}
# > Running step 4e679e66-68f4-4178-a389-c1dbdf3908c0. Step input: None
# === LLM Response ===
# Based on the information provided by the tools, I can identify two high-profile politicians who have recently traded NVDA (NVIDIA Corporation) stock:
#
# 1. Senator Tommy Tuberville (Republican - Alabama):
#    - Transaction: Sale (Full)
#    - Date: April 30, 2024
#    - Amount: $15,001 - $50,000
#    - Ownership: Joint
#
# 2. Representative Pete Sessions (Republican - Texas, 17th District):
#    - Transaction: Purchase
#    - Date: September 16, 2024
#    - Amount: $1,001 - $15,000
#    - Ownership: Spouse
#
# These are the most recent and notable politicians trading NVDA stock according to the data provided. Let's break down why these trades are significant:
#
# 1. Senator Tommy Tuberville:
#    - Tuberville has been a high-profile figure in discussions about congressional stock trading due to his frequent trading activities.
#    - His sale of NVDA stock is noteworthy because it was a full sale of a relatively substantial amount ($15,001 - $50,000).
#    - The timing of his sale (April 2024) could be of interest given NVIDIA's strong performance in the AI boom.
#
# 2. Representative Pete Sessions:
#    - Sessions is a long-serving member of Congress and has held leadership positions in the House.
#    - While the amount of his NVDA purchase is smaller, it's notable that it's a recent purchase (September 2024) made by his spouse.
#    - The timing of this purchase could be interesting to analysts looking at congressional trading patterns.
#
# It's important to note:
#
# 1. The data shows only the most recent trades for each chamber of Congress. There might have been other politicians trading NVDA stock in the past, but they are not reflected in this most recent data.
#
# 2. Tuberville's trade was a sale, while Sessions' was a purchase, which could indicate different views on the stock's future performance or could be part of their regular portfolio management.
#
# 3. The exact motivations behind these trades are not provided in the disclosure data. Politicians are required to disclose their trades for transparency, but the reasons for their investment decisions are not typically included.
#
# 4. Both of these politicians are Republicans, which is just a coincidence in this most recent data and doesn't
# Based on the information provided by the tools, I can identify two high-profile politicians who have recently traded NVDA (NVIDIA Corporation) stock:
#
# 1. Senator Tommy Tuberville (Republican - Alabama):
#    - Transaction: Sale (Full)
#    - Date: April 30, 2024
#    - Amount: $15,001 - $50,000
#    - Ownership: Joint
#
# 2. Representative Pete Sessions (Republican - Texas, 17th District):
#    - Transaction: Purchase
#    - Date: September 16, 2024
#    - Amount: $1,001 - $15,000
#    - Ownership: Spouse
#
# These are the most recent and notable politicians trading NVDA stock according to the data provided. Let's break down why these trades are significant:
#
# 1. Senator Tommy Tuberville:
#    - Tuberville has been a high-profile figure in discussions about congressional stock trading due to his frequent trading activities.
#    - His sale of NVDA stock is noteworthy because it was a full sale of a relatively substantial amount ($15,001 - $50,000).
#    - The timing of his sale (April 2024) could be of interest given NVIDIA's strong performance in the AI boom.
#
# 2. Representative Pete Sessions:
#    - Sessions is a long-serving member of Congress and has held leadership positions in the House.
#    - While the amount of his NVDA purchase is smaller, it's notable that it's a recent purchase (September 2024) made by his spouse.
#    - The timing of this purchase could be interesting to analysts looking at congressional trading patterns.
#
# It's important to note:
#
# 1. The data shows only the most recent trades for each chamber of Congress. There might have been other politicians trading NVDA stock in the past, but they are not reflected in this most recent data.
#
# 2. Tuberville's trade was a sale, while Sessions' was a purchase, which could indicate different views on the stock's future performance or could be part of their regular portfolio management.
#
# 3. The exact motivations behind these trades are not provided in the disclosure data. Politicians are required to disclose their trades for transparency, but the reasons for their investment decisions are not typically included.
#
# 4. Both of these politicians are Republicans, which is just a coincidence in this most recent data and doesn't
